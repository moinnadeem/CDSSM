# %%
cd ..
# Out:
# /data/sls/u/urop/mnadeem/CDSSM_github

# %%
import pytorch_data_loader
import joblib

# %%
claims_dict = joblib.load("new_claims_dict.pkl")
train = joblib.load("train_small.pkl")

# %%
dataset = pytorch_data_loader.WikiDataset(train, claims_dict)
# Out:
# Num Distinct Claims 109810
# Num Data Points 125050

# %%
# %load_ext line_profiler
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-df8a33df4eaf> in <module>
# ----> 1 get_ipython().run_line_magic('load_ext', 'line_profiler')
#
# /data/sls/u/urop/mnadeem/my_venv/lib/python3.5/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2285                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2286             with self.builtin_trap:
# -> 2287                 result = fn(*args,**kwargs)
#    2288             return result
#    2289
#
# <decorator-gen-65> in load_ext(self, module_str)
#
# /data/sls/u/urop/mnadeem/my_venv/lib/python3.5/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
# ...
