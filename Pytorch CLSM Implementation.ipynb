# %% [markdown]
# # Implementing CLSM

# %% [markdown]
# ## Purpose
# The purpose of this notebook is to implement Microsoft's [Convolutional Latent Semantic Model](http://www.iro.umontreal.ca/~lisa/pointeurs/ir0895-he-2.pdf) on our dataset.
#
# ## Inputs
# - This notebook requires *wiki-pages* from the FEVER dataset as an input.

# %% [markdown]
# ## Preprocessing Data

# %%
import cdssm
import numpy as np
import nltk
import utils
import pickle

from scipy import sparse
from joblib import Parallel, delayed
from multiprocessing import cpu_count
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from tqdm import tqdm_notebook

# %%
claims, labels, article_list, claim_set, claim_to_article = utils.extract_fever_jsonl_data("../train.jsonl")
# Out:
# Num Distinct Claims 109810
# Num Data Points 125051

# %%
claim_to_article
# Out:
# {'Robert F. Kennedy defeated Senator Eugene McCarthy in the Ohio primaries.': ['robert f  kennedy'],
#  'The Odyssey has been translated into ancient dialects.': ['odyssey'],
#  'Big Bang won 7 awards at the 9th MTV Video Music Awards Japan.': ['big bang  south korean band '],
#  'Priyanka Chopra is an Indian singer.': ['priyanka chopra',
#   'priyanka chopra'],
#  'Oz the Great and Powerful was released in conventional theaters 2016.': ['oz the great and powerful'],
#  'Cosmopolitan contains content as of 2011 which includes articles on celebrities.': ['cosmopolitan  magazine '],
#  'One Teen Choice Award was won by Anne Hathaway.': ['anne hathaway'],
#  'Star Wars: Episode II – Attack of the Clones came out on Blu-ray disc.': ['star wars colon  episode ii – attack of the clones'],
#  '24 premiered in November.': ['24  tv series '],
#  'Jane Eyre was originally published as Jane Eyre: An Autobiography.': ['jane eyre'],
#  'Emily Browning was passed over for a role in Sucker Punch.': ['emily browning'],
#  'Athena is an Norse goddess.': ['athena'],
#  'Hayden Panettiere is not an actress.': ['hayden panettiere'],
#  'The director of the pilot episode of The Blacklist was born in 1969.': ['the blacklist  tv series ',
#   'joe carnahan'],
#  'Florence Pugh had a role in The Falling.': ['the falling  2014 film '],
#  'Gabourey Sidibe made her acting debut in House of Lies.': ['gabourey sidibe'],
#  'William Jennings Bryan had a job.': ['william jennings bryan'],
#  "Michael Jackson's sexual abuse accusation was settled without criminal charges.": ['michael jackson'],
#  'Chloë Sevigny stars in Love & Friendship.': ['love   friendship'],
#  'Darth Vader is the leader of the Galactic Empire.': ['darth vader'],
#  'Don Simpson and Jerry Bruckheimer produced Top Gun.': ['don simpson'],
#  'Nina Simone went to school some time after 1356.': ['nina simone'],
#  'Ranbir Kapoor is one of the highest-paid swimmers in India.': ['ranbir kapoor'],
#  'Harmanpreet Kaur was born on March 8.': ['harmanpreet kaur'],
#  'Semitic languages are used in the Horn of Africa.': ['semitic languages'],
#  'Bradford is in France.': ['bradford'],
#  'The French Revolution provoked changes.': ['french revolution'],
#  'Tyrese Gibson is well known for his role as Joseph "Jody" Summers in Baby Boy.': ['tyrese gibson',
#   'tyrese gibson'],
#  'Don Henley and Glenn Frey cowrote most Eagles songs.': ['glenn frey'],
#  'The Chronicles of Narnia is a series of films.': ['the chronicles of narnia  film series '],
#  'The Craft is a movie of the supernatural horror genres.': ['the craft  film '],
#  'Atomic Blonde is based on The Coldest City.': ['atomic blonde',
#   'atomic blonde'],
#  'Previously unknown athletes get a chance to shine at the Olympic Games.': ['olympic games'],
#  'Thailand is smaller than 49 other countries, with a total area of approximately 513,000 square kilometers.': ['thailand'],
#  'Daniel Craig was born in 1991.': ['daniel craig'],
#  'Unforgettable was written by Christina Hodson and David Leslie Johnson.': ['unforgettable  2017 film '],
#  'Mel Brooks is an entertainer.': ['mel brooks'],
#  'Billy Joel is in the performing arts industry.': ['billy joel'],
#  'Tony Bill directed a film written by anyone except Alan Ormsby.': ['tony bill',
#   'my bodyguard'],
#  'Nas is a musician who has received acclaim.': ['nas'],
#  'Austria signed the Austrian State Treaty in 1066.': ['austria'],
#  'Led Zeppelin II was produced by Led Zeppelin.': ['led zeppelin ii'],
#  'George Washington did not contribute to the establishment of the United States of America.': ['george washington'],
#  'The 1998 Major League Baseball All-Star Game was held at the home of the Colorado Rockies, Coors Field.': ['1998 major league baseball all star game'],
#  "Charlie Chaplin's childhood was one of destitution.": ['charlie chaplin'],
#  'Ted Kaczynski sent a letter to a newspaper.': ['ted kaczynski',
#   'the new york times'],
#  'There is healthcare and education in North Korea.': ['north korea'],
#  'The Danish Girl is based on a 2011 novel by David Ebershoff.': ['the danish girl  film '],
#  'Abraham Lincoln helped to build the new Republican Party.': ['abraham lincoln'],
#  "Hayley Atwell's date of birth is April 5th, 1982.": ['hayley atwell'],
#  'Lost Highway (film) was written by American director David Lynch.': ['lost highway  film '],
#  "Elephants' habitats include lions.": ['elephant'],
#  'Angelina Jolie played a female character based on a video game.': ['angelina jolie'],
#  'Nick Kroll has been in the cast of comedy films.': ['nick kroll',
#   'a good old fashioned orgy',
#   'adult beginners',
#   'date night',
#   'dinner for schmucks',
#   'get him to the greek',
#   'joshy  film '],
#  'Ronald Reagan is still in office.': ['ronald reagan'],
#  'Clint Eastwood is a person who acts.': ['clint eastwood'],
#  'José María Chacón only surrendered the island of Trinidad to an American fleet.': ['josé maría chacón'],
#  'Andrew Wood (singer) is a singer.': ['andrew wood  singer '],
#  'Emily Ratajkowski was born in London.': ['emily ratajkowski'],
#  "Lisa Kudrow was in Romy and Michele's High School Reunion.": ['lisa kudrow'],
#  "British Columbia's economic mainstay is logging, farming, and mining.": ['british columbia'],
#  'Ruth Negga has worked in television in the United Kingdom.': ['ruth negga',
#   'bbc'],
#  'Nina Simone supported the Civil Rights Movement.': ['nina simone'],
#  'Caroline, Princess of Hanover is married to a man.': ['caroline  princess of hanover'],
#  'Glamorous is a song.': ['glamorous  fergie song '],
#  'Valerian and the City of a Thousand Planets stars an actor.': ['valerian and the city of a thousand planets',
#   'dane dehaan'],
#  "Kirk Douglas's professions include actor, producer, director, and author.": ['kirk douglas'],
#  'Jeremy Allen White is an American television director.': ['jeremy allen white'],
#  'There is a Christian state called England.': ['christian state'],
#  'Ancient Egypt began in 3150 BC under the first pharaoh, Narmer.': ['ancient egypt'],
#  'Ty Cobb spent 22 seasons with the Dallas Cowboys.': ['ty cobb'],
#  'John Lennon was inducted into the Rock and Roll Hall of Fame multiple times.': ['john lennon'],
#  'Veronica Mars is a character.': ['veronica mars  character ',
#   'character  arts '],
#  'David Carradine starred in the television series Kung Fu in the 1970s.': ['david carradine'],
#  'Vanilla Sky stars an actress from Spain.': ['vanilla sky', 'penélope cruz'],
#  'Alison Brie is American.': ['alison brie'],
#  "Prison Break was the winner of a People's Choice Award.": ['prison break'],
#  'The 2016 Summer Olympics was not a sport event.': ['2016 summer olympics'],
#  'Trent Reznor is a performer.': ['trent reznor'],
#  'The only thing seminary prepares its students for is a career in information sciences.': ['seminary'],
#  'Fifty Shades of Grey has been translated into 52 languages.': ['fifty shades of grey'],
#  'Tanzania does not have a parliamentary system.': ['tanzania'],
#  'In 2017, the 7th season of Game of Thrones came out.': ['game of thrones'],
#  'The Weeknd is a Canadian person.': ['the weeknd'],
#  "The Great Debaters' cast includes Forest Whitaker.": ['the great debaters'],
#  'Black Mirror was first broadcast on CBS.': ['black mirror'],
#  'Outlander is based on the Outlander series.': ['outlander  tv series '],
#  'The Olympic Games give athletes the chance to attain fame both nationally and internationally.': ['olympic games'],
#  'Broadchurch is not a television crime drama.': ['broadchurch'],
#  'Azerbaijan was the earliest democratic republic in the Muslim world.': ['azerbaijan'],
#  'Apple was incorporated as Apple Computer, Inc. in January 1977.': ['apple inc '],
#  'Dracula was a vampire.': ['dracula'],
#  'Investment funds is the universal term for this type of investment.': ['investment fund'],
#  'The Philippines refused to make the national fruit a mango.': ['mango'],
#  'There is an American film named The Crazies.': ['the crazies  2010 film '],
#  'The Supremes were a girl group in the 1960s.': ['the supremes'],
#  'Colombia is in North America.': ['colombia'],
#  'Hisense only used the brand name of a former Chinese firm.': ['hisense'],
#  'Laurence Olivier was a self-governing actor-manager.': ['laurence olivier'],
#  "Tall Story's actress Jane Fonda was 22 years old during filming.": ['tall story'],
#  'Zeus was the king of pants.': ['zeus'],
#  'Tim Robbins failed to ever have a career producing.': ['tim robbins'],
#  'Bradford contains a museum.': ['bradford'],
#  'Michael Fassbender appeared in a 2013 British-American thriller film.': ['michael fassbender',
#   'the counselor'],
#  'Marion Cotillard played a French cabaret singer in La Vie en Rose (2007).': ['marion cotillard',
#   'édith piaf'],
#  'Stars Dance is only a single.': ['stars dance'],
#  'Ghost in the Shell was developed by a company.': ['ghost in the shell  video game ',
#   'production i g'],
#  'Stranger Things includes a character who is capable of psychokinesis.': ['stranger things'],
#  'There are zero bodies of water in Ontario.': ['ontario',
#   'ontario',
#   'ontario',
#   'ontario',
#   'ontario',
#   'ontario',
#   'ontario'],
#  'Mike Myers had a small role in a 2009 fantasy film.': ['mike myers',
#   'inglourious basterds'],
#  'Calling All the Monsters was found through an American record label.': ['calling all the monsters',
#   'walt disney records'],
#  'Deadpool appears in Marvel Comics.': ['deadpool'],
#  'Judith Quiney passed away on February 9, 1662.': ['judith quiney'],
#  'Wyatt Earp was a hunter.': ['wyatt earp'],
#  'George Bernard Shaw wrote the novel Major Barbara.': ['george bernard shaw'],
#  'Performance (film) is the singing debut of Mick Jagger.': ['performance  film ',
#   'the rolling stones'],
#  'Howard Hughes built the Hughes H-1 Racer in the 1930s.': ['howard hughes'],
#  'Jordan Knight was born on May 17, 1950.': ['jordan knight'],
#  'Robert Carlock worked on Whiskey Tango Foxtrot.': ['whiskey tango foxtrot  film '],
#  'Iron Fist was created for Hulu.': ['iron fist  tv series '],
#  'Black Sabbath only formed in 1942.': ['black sabbath'],
#  'Khal Drogo was introduced in a novel.': ['khal drogo', 'a game of thrones'],
#  'Plutonium only reacts with iron.': ['plutonium', 'plutonium'],
#  'Jennifer Grey is incapable of being an actress.': ['jennifer grey'],
#  'Jackie Evancho was a model.': ['jackie evancho'],
#  'Adolf Hitler caused the murder of at least 5.5 million Jews.': ['adolf hitler'],
#  'Moses Malone won an MVP in 1982.': ['moses malone'],
#  'Julie Walters was in series.': ['julie walters',
#   'julie walters',
#   'julie walters',
#   'julie walters'],
#  'Maria Sharapova retired from tennis by 2000.': ['maria sharapova',
#   'list of wta number 1 ranked tennis players'],
#  'Alan Rickman was born in 1946.': ['alan rickman'],
#  'Roy Whiting was born on January 26, 1959.': ['roy whiting'],
#  'Bangalore was run by the Maharaja of Mysore.': ['bangalore'],
#  'Stay was released by Alessia Cara.': ['alessia cara',
#   'stay  zedd and alessia cara song '],
#  'Belgium is comprised of three regions.': ['belgium'],
#  'Taylor Schilling made her film debut after 2001.': ['taylor schilling',
#   'dark matter  film '],
#  'William Shakespeare did not write tragicomedies.': ['william shakespeare'],
#  'Nelson Mandela is without a middle name.': ['nelson mandela'],
#  'Sansa Stark was destroyed by an author.': ['sansa stark'],
#  'The occupation of Austria ended in 1955.': ['austria'],
#  'Hearing loss may be caused by birth complications.': ['hearing loss'],
#  'The Promise has a Dutch director.': ['the promise  2016 film ',
#   'terry george'],
#  'Augusto Pinochet died in 2016.': ['augusto pinochet'],
#  'The Breakfast Club was directed by Angela Merkel.': ['the breakfast club'],
#  "Sindh borders India's largest state.": ['sindh', 'rajasthan'],
#  'Evonne Goolagong Cawley was born on July 31st, 1951.': ['evonne goolagong cawley'],
#  'Goat Island is connected to only one bridge.': ['goat island  new york '],
#  'Amazon.com sells media files.': ['amazon com'],
#  'Yamaha Corporation is a Japanese electronics corporation.': ['yamaha corporation'],
#  'Qatar is not a movie.': ['qatar'],
#  'Jennifer Grey was born on the 26th.': ['jennifer grey'],
#  'In the 1964 United States presidential election, Lyndon B. Johnson defeated Barry Goldwater.': ['lyndon b  johnson'],
#  'R. Kelly has sold over 100 million records.': ['r  kelly'],
#  'George Best is European.': ['george best'],
#  'Here Comes the Sun was recorded at Abbey Road Studios in London in 1969.': ['here comes the sun'],
#  'Ricky Martin is a modest star in Mexico.': ['ricky martin'],
#  'Steve Mouzakis refused to play the character Steven Ray.': ['steve mouzakis'],
#  'Patch Adams (film) is a film that was incapable of starring Monica Potter.': ['patch adams  film '],
#  'Shirley MacLaine has won a BAFTA for Best Foreign Actress for Ask Any Girl and The Apartment.': ['shirley maclaine'],
#  'Kirk Douglas acted in Lonely Are the Brave.': ['kirk douglas'],
#  "Chris Evans' (actor) directorial debut was Before We Go.": ['chris evans  actor '],
#  'Gift of the Night Fury stars the voice of an actor whose birthday is on November 13.': ['gift of the night fury',
#   'gerard butler'],
#  'Katrina Bowden appeared on 30 Rock.': ['30 rock'],
#  'David Dhawan is only a film producer.': ['david dhawan'],
#  'Romelu Lukaku plays in Europe.': ['romelu lukaku',
#   'belgium national football team'],
#  'Fairfield Grammar School was called Fairfield Secondary and Higher Grade School when it was founded.': ['fairfield grammar school'],
#  'Ramona Marquez played the role of Karen Brockman.': ['ramona marquez'],
#  'The Italian Republic is the proper term for Italy.': ['italy'],
#  'The 1992 Los Angeles riots occurred in 2000.': ['1992 los angeles riots'],
#  'Thomas Haden Church is the director of the film Rolling Kansas.': ['thomas haden church'],
#  "Carol Leifer's comedy career began in the 1980s.": ['carol leifer'],
#  'Paul Pogba ended his career in 2011.': ['paul pogba', 'paul pogba'],
#  'Evil is frequently associated with revenge.': ['evil'],
#  "Vladimir Putin's birth place is in Russia's second-largest city.": ['vladimir putin',
#   'saint petersburg'],
#  'True Blood is dark fantasy.': ['true blood'],
#  'Iraq is not in Western Asia.': ['iraq'],
#  'Elisabeth Sladen semi-retired in the 1980s.': ['elisabeth sladen'],
#  'Notes on a Scandal was nominated for The Academy Award for Best Adapted Screenplay.': ['notes on a scandal  film '],
#  'Justified won two awards.': ['justified  tv series '],
#  'Guardians of the Galaxy was released on a date.': ['guardians of the galaxy  film '],
#  'The 2017 Open Championship is not a golf championship.': ['2017 open championship'],
#  'Reddit had a funding round that included American investors.': ['reddit',
#   'sam altman',
#   'ron conway',
#   'marc andreessen',
#   'snoop dogg',
#   'jared leto',
#   'peter thiel'],
#  'The West Wing contains the Roosevelt Room.': ['west wing'],
#  'Paul Newman has won something.': ['paul newman'],
#  'Anne Frank was not born in a city in Germany.': ['anne frank'],
#  'True Blood is from the United States.': ['true blood'],
#  'New Orleans is the 6th largest population in the United States.': ['new orleans'],
#  'Hayden Panettiere is a person.': ['hayden panettiere'],
#  'Evan Rachel Wood has been featured in Whatever Works.': ['evan rachel wood'],
#  'The Kingdom of Georgia fell to invasions.': ['kingdom of georgia'],
#  'Edward Norton has contributed to the writing in films.': ['edward norton'],
#  "Miss Peregrine's Home for Peculiar Children had an editor.": ['miss peregrine s home for peculiar children'],
#  'The Big Trail was released in 1930.': ['the big trail'],
#  'Hawaii is not densely populated.': ['hawaii'],
#  'Helios is the male spawn of Titans.': ['helios'],
#  'Ubisoft is the name the company Ubisoft Entertainment SA is doing business as.': ['ubisoft'],
#  'Blizzard Entertainment made the Diablo video game series.': ['blizzard entertainment',
#   'diablo  series '],
#  'Cher has won a special CFDA Fashion Award.': ['cher'],
#  'Break on Me was released through a record label.': ['break on me',
#   'capitol records nashville',
#   'break on me',
#   'capitol records nashville'],
#  'Bad Boys II has Gabrielle Union in it.': ['gabrielle union'],
#  'Luke Evans acted the part of Gaston in Beauty and the Beast.': ['luke evans  actor '],
#  'Jacki Weaver refused to work on Alvin Purple.': ['jacki weaver'],
#  'Rock music avoids incorporating music genres like folk.': ['rock music'],
#  'Freddie Mercury is no longer living.': ['freddie mercury'],
#  'The OA did not premiere on December 16, 2016.': ['the oa'],
#  'Man of Steel (film) starred Michael Shannon.': ['man of steel  film '],
#  'Devdas was unable to be screened at the 2002 Cannes Film Festival.': ['devdas  2002 hindi film '],
#  'Jon Pertwee was in a series from 1987 to 1989.': ['jon pertwee'],
#  'Inside Man is a movie.': ['inside man'],
#  'Evan Rachel Wood acted in Once and Again.': ['evan rachel wood'],
#  "Constantine's screenplay only writer was Christopher Nolan.": ['constantine  film '],
#  'Brock Lesnar fought a South Korean person.': ['brock lesnar',
#   'kim min soo  judoka '],
#  'Harold Ramis directed.': ['harold ramis'],
#  'Lewis Hamilton has multiple F1 titles.': ['lewis hamilton',
#   '2015 formula one season',
#   '2014 formula one season'],
#  'Slovakia is a nation.': ['slovakia', 'landlocked country'],
#  'Jared Kushner is a North American.': ['jared kushner'],
#  'Prison Break was originally planned for a multiple-episode run.': ['prison break'],
#  'Splatoon 2 is not developed by Nintendo.': ['splatoon 2'],
#  'Cate Blanchett won multiple acting Oscars.': ['cate blanchett'],
#  'The largest urban area of Australia is the most populous city in Australia and Oceania.': ['australia',
#   'sydney'],
#  'Adam Sandler was the only person ever to voice act in Hotel Transylvania 2.': ['hotel transylvania 2'],
#  'The Promise was released in the United States in 2017.': ['the promise  2016 film '],
#  'How to Train Your Dragon (film) failed to win the Academy Award for Best Original Score at the 83rd Academy Awards.': ['how to train your dragon  film '],
#  "James Taylor's Greatest Hits album sold 12 million US copies.": ['james taylor'],
#  "Vlad the Impaler's male sibling is called Mircea.": ['vlad the impaler'],
#  'One Direction won awards.': ['one direction'],
#  'Wild Ones is by Flo Rida.': ['wild ones  song '],
#  'Transformers: The Last Knight stars Josh Duhamel.': ['transformers colon  the last knight'],
#  'Josh Duhamel is employed by the film industry.': ['josh duhamel'],
#  'Funny or Die is a production company.': ['funny or die'],
#  'Bill Gates was born in 1978.': ['bill gates'],
#  'Morena Baccarin received an award nomination.': ['morena baccarin'],
#  'Marlon Brando has been awarded at least two Academy Awards.': ['marlon brando'],
#  'Inside Man is a motion picture.': ['inside man'],
#  'Glenn Frey has only ever worked with Don Henley.': ['glenn frey',
#   'eagles  band '],
#  'Sons of Anarchy is not about a motorcycle club.': ['sons of anarchy'],
#  'Starbucks annually launches their Pumpkin Spice Latte in the fall.': ['starbucks'],
#  'Carrie Fisher wrote an autobiography.': ['carrie fisher',
#   'wishful drinking'],
#  'Rockefeller University is in a state.': ['new york',
#   'rockefeller university'],
#  'Walt Whitman volunteered during the American Civil War in 1933.': ['walt whitman'],
#  'Martin Freeman is an English actor.': ['martin freeman'],
#  'Canada was a British colony in South America.': ['canada'],
#  'Dogstar (band) performed at the Glastonbury Festival.': ['dogstar  band '],
#  'Yelp existed in the 21st century.': ['yelp'],
#  'Game of Thrones is a television show.': ['game of thrones'],
#  'John Wayne Gacy buried 26 victims and was later caught.': ['john wayne gacy'],
#  'A Golden Globe was given to Jason Bateman.': ['jason bateman'],
#  'Charles, Prince of Wales has not sought to raise world awareness of the dangers facing the natural environment, such as climate change.': ['charles  prince of wales'],
#  "Robert Wagner and Scott Eyman wrote Wagner's autobiography.": ['robert wagner'],
#  'The Bends was released by UPS.': ['the bends'],
#  'In & Out is an Indian film.': ['in   out  film '],
#  'Neymar is Brazilian.': ['neymar'],
#  'The Beastie Boys had at least five studio albums.': ['beastie boys'],
#  'The terrain of Kazakhstan includes rock canyons.': ['kazakhstan'],
#  'Kajal Aggarwal has an acting career.': ['kajal aggarwal'],
#  'Will Ferrell wrote Step Brothers with Adam McKay.': ['will ferrell',
#   'the other guys'],
#  'Meryl Streep began acting professionally in 1980.': ['meryl streep'],
#  "Judd Apatow's films have received a nomination for a Tony Award.": ['judd apatow',
#   'tony award'],
#  'Drax the Destroyer was created.': ['drax the destroyer'],
#  'Cedric Yarbrough has been in a television show.': ['cedric yarbrough'],
#  'Vikram is an Indian actor.': ['vikram  actor '],
#  'Lynyrd Skynyrd permanently disbanded after the death of its first lead vocalist.': ['lynyrd skynyrd'],
#  'Harry Potter was written by an Icelandic author.': ['harry potter',
#   'j  k  rowling'],
#  'Hitler was never appointed as Chancellor of Germany.': ['adolf hitler'],
#  'Michael Jackson was killed via a particular type of homicide.': ['michael jackson',
#   'manslaughter'],
#  'Law of value appeared first in a book called death.': ['law of value'],
#  'Karl Malone has always been incapable of playing basketball.': ['karl malone',
#   'power forward  basketball '],
#  'Elephants have been highlighted in religion.': ['elephant'],
#  "The Invention of Lying's cast includes Jennifer Garner.": ['the invention of lying'],
#  'John Bradley-West is a Japanese actor.': ['john bradley west'],
#  'Tina Turner put out a solo album.': ['tina turner'],
#  'Resident Evil is about zombie outbreaks caused by the T-Virus.': ['resident evil'],
#  'There is a province called Newfoundland and Labrador.': ['newfoundland and labrador'],
#  'War Dogs features Ana de Armas.': ['war dogs  2016 film '],
#  'Las Vegas is the largest city within Utah.': ['las vegas'],
#  'Mother Teresa lived in Macedonia for eighteen years.': ['mother teresa'],
#  "Franklin D. Roosevelt's strategy barely ended in the defeat of the Axis Powers.": ['franklin d  roosevelt'],
#  'Michelangelo did sculptures.': ['michelangelo'],
#  'The Craft is a 1996 novel.': ['the craft  film '],
#  'Sarah Paulson portrayed Harriet Hayes.': ['sarah paulson'],
#  'On May 17, 1970, Jordan Knight was born.': ['jordan knight'],
#  'South America is home to the Amazon River, the largest river in the world.': ['south america',
#   'amazon river'],
#  'Poppy (singer) is also known as "That Poppy."': ['poppy  singer '],
#  "Take a Bow is the second single off of Madonna's sixth album.": ['take a bow  madonna song '],
#  'Ice hockey has only domestic competitions.': ['ice hockey'],
#  'The Santos FC is a Brazil sports club.': ['santos fc'],
#  "Red Headed Stranger's lyrics have been featured in the comic Preacher.": ['red headed stranger'],
#  "Islam didn't have a prophet named Muhammad.": ['islam',
#   'khatam an nabiyyin',
#   'muhammad'],
#  'Fred Trump was thirteen years old in December, 1918.': ['fred trump',
#   'frederick trump'],
#  'The Godfather Part III was nominated for an award for Most Valuable Player.': ['the godfather part iii',
#   'most valuable player'],
#  'Dragon is related to something.': ['dragon'],
#  "The Dark Knight Rises' filming took place in New Jersey.": ['the dark knight rises',
#   'newark  new jersey'],
#  'Charlize Theron acted in a film directed by Guillermo Arriaga.': ['charlize theron',
#   'the burning plain'],
#  'Denial premiered at the Sundance Film Festival.': ['denial  2016 film '],
#  'Amsterdam Airport Schiphol serves as a European hub for Jet Airways.': ['amsterdam airport schiphol'],
#  'Drama school offers zero degrees.': ['drama school',
#   'drama school',
#   'drama school'],
#  'Maya Rudolph appeared in the film Grown Ups.': ['maya rudolph'],
#  'Radioactive received an honor from The Recording Academy.': ['radioactive  imagine dragons song ',
#   'grammy award'],
#  'George Best scored zero goals.': ['george best'],
#  'Tré Cool is a physician, plumber, and garbage man.': ['tré cool'],
#  'Tyrese Gibson is famous for his part in the Transformers film series.': ['tyrese gibson'],
#  "The Dark Knight was released six months after Ledger's death.": ['the dark knight  film '],
#  'Eddie Vedder has done solo music work.': ['eddie vedder'],
#  'The Divergent Series: Allegiant fails to be based on a work by Veronica Roth.': ['the divergent series colon  allegiant'],
#  'O. J. Simpson was arrested in 2009.': ['o  j  simpson'],
#  'The Wars of the Roses occurred in England.': ['wars of the roses'],
#  '2017 was the year when The Fate of the Furious was premiered.': ['the fate of the furious'],
#  'Saswata Chatterjee works as a film actor.': ['saswata chatterjee'],
#  'Following was directed by Christopher Nolan.': ['following'],
#  'The Council on Foreign Relations was founded in America.': ['council on foreign relations'],
#  'K2 is 8611 centimeters above sea level.': ['k2'],
#  'Jon Pertwee took part in Worzel Gummidge.': ['jon pertwee'],
#  'The subject of The Prestige is stage magic.': ['the prestige  film '],
#  'Carbon has 6 as its atomic number.': ['carbon'],
#  'John Stewart was the first African American superhero to be featured in a film.': ['john stewart  comics '],
#  'The World Science Festival is unaffiliated with the World Science Foundation.': ['world science festival'],
#  'The phalanx appears in Greek texts.': ['phalanx'],
#  "Natalie Wood's birthday is May 20.": ['natalie wood'],
#  'Eddie Redmayne is a person.': ['eddie redmayne'],
#  'Alicia Silverstone played Batgirl.': ['alicia silverstone'],
#  'The Void is a motion picture.': ['the void  2016 film '],
#  'The Bulls were in the 1991 NBA Finals.': ['1991 nba finals'],
#  'Gary Ridgway worked in Washington.': ['gary ridgway'],
#  'Adam West was born in 1923.': ['adam west'],
#  "Dr. Dre's solo album is called 2001.": ['dr  dre'],
#  'Freddie Mercury received an award.': ['freddie mercury'],
#  'Tyrion Lannister is portrayed by an actor.': ['tyrion lannister'],
#  'Gil Sharone began working with an American rock band.': ['gil sharone',
#   'marilyn manson  band '],
#  'Houston has a population from various ethnic and racial backgrounds.': ['houston'],
#  "Tanzania's former capital city and principal port is Dar es Salaam.": ['tanzania'],
#  'Humanz includes collaborative piece done with Pusha T.': ['humanz'],
#  'The Dodecanese belong to Greece.': ['dodecanese', 'southern sporades'],
#  'Precious premiered to acclaim at the 2009 Cannes Film Festival.': ['precious  film '],
#  'Boromir appears in The Fellowship of the Panther God.': ['boromir'],
#  'Slipknot is a solo musician.': ['slipknot  band '],
#  'Rhode Island renounced its allegiance to the British Crown.': ['rhode island'],
#  'Dan Aykroyd was in an American comedy-drama film from 1989.': ['dan aykroyd',
#   'driving miss daisy'],
#  'Michelle Obama is married to Barack Obama.': ['michelle obama',
#   'michelle obama'],
#  "Selena Gomez's album is called Revival.": ['selena gomez'],
#  'Zooey Deschanel is from America.': ['zooey deschanel'],
#  'Mike Tyson was disqualified.': ['mike tyson'],
#  "Miss Peregrine's Home for Peculiar Children is only a German film.": ['miss peregrine s home for peculiar children  film '],
#  'Rio de Janeiro is not in the Americas.': ['rio de janeiro'],
#  "The Eagles' guitarist is Joe Walsh who joined in 1975.": ['eagles  band '],
#  'Adrienne Bailon is practiced in music.': ['adrienne bailon'],
#  "The World Science Festival's producer is the World Science Foundation.": ['world science festival'],
#  'Quentin Tarantino directed Kill Bill: Volume 2.': ['kill bill colon  volume 2'],
#  'Lilith translates to "night monster."': ['lilith', 'lilith'],
#  'Ellyse Perry played baseball at the age of 16.': ['ellyse perry'],
#  "Nina Simone's hometown is in North Carolina.": ['nina simone'],
#  "Turn: Washington's Spies was renewed for a third 10-episode season.": ['turn colon  washington s spies',
#   'turn colon  washington s spies'],
#  'Cleopatra (1963 film) is an American comedy film.': ['cleopatra  1963 film '],
#  "Helen Keller did not campaign for women's suffrage.": ['helen keller'],
#  'Linda McCartney was diagnosed with breast cancer in 1995.': ['linda mccartney'],
#  'John Glenn was the first American astronaut to orbit the Earth.': ['john glenn'],
#  'The Sopranos was first broadcast on A&E in 2011.': ['the sopranos'],
#  'Steve Coogan is incapable of acting.': ['steve coogan'],
#  'The Bostonians (film) is a 1984 film.': ['the bostonians  film '],
#  'Ethiopia is in the peninsula the Horn of Africa.': ['ethiopia',
#   'horn of africa'],
#  'Quinoa is a common name for a plant.': ['quinoa'],
#  'American Gods is an American television series.': ['american gods  tv series '],
#  'Alpha House is inspired by nobody.': ['alpha house',
#   'alpha house',
#   'alpha house',
#   'alpha house'],
#  "Rumi's art is widely read.": ['rumi'],
#  'Thirteen was directed by Catherine Hardwicke in 2001.': ['thirteen  2003 film '],
#  'Arrow is a TV series on the CW.': ['arrow  tv series '],
#  'Warren G. Harding died in 1865.': ['warren g  harding'],
#  'Arnold Schwarzenegger was involved with work by a Canadian filmmaker, director, producer, screenwriter, inventor, engineer, philanthropist, and deep-sea explorer name James Cameron.': ['arnold schwarzenegger',
#   'james cameron'],
#  'There are only 300 members total in US Congress.': ['united states congress'],
#  'Kathy Bates rose to prominence with her performance in Misery in 2005.': ['kathy bates'],
#  'One game sequel is Super Metroid.': ['super metroid'],
#  'The Flash was written by Danny Bilson and Paul De Meo.': ['the flash  1990 tv series '],
#  'The Crown (TV series) starred Steve Martin.': ['the crown  tv series '],
#  'Ariana Grande had one album prior to her album My Everything.': ['ariana grande'],
#  'The Belko Experiment was not written by James Gunn.': ['the belko experiment'],
#  'Sierra Leone became an independent nation on April 27 1961.': ['sierra leone'],
#  'Matthew Weiner created Mad Men.': ['mad men'],
#  'Portia de Rossi starred as Olivia Lord.': ['portia de rossi'],
#  'Ivan Lendl is a tennis pebble.': ['ivan lendl'],
#  'Sunrise created anime from 1979 to 2008.': ['sunrise  company ',
#   'gundam',
#   'inuyasha'],
#  'Cambodia have minority groups like Chinese.': ['cambodia'],
#  "Grace Jones's style was influenced by funk.": ['grace jones'],
#  "Tall Story's director was born in the 1900's.": ['tall story'],
#  'The Harry Potter series has been translated into many languages.': ['harry potter'],
#  'Earl Warren worked as a governor.': ['earl warren'],
#  'Dexter features the character Lumen Pierce.': ['lumen pierce'],
#  'Aruba has a climate.': ['aruba'],
#  'Marlon Brando was included in a list.': ['marlon brando'],
#  'Courteney Cox appeared on a sitcom.': ['courteney cox'],
#  'The Mughal Empire was ruled by a dynasty.': ['mughal empire'],
#  'Me Before You is a romantic drama film released in 2017.': ['me before you  film '],
#  'X-Men: Days of Future Past came out in 2016.': ['x men colon  days of future past'],
#  'Dolly Parton starred in the comedy 9 to 5.': ['dolly parton'],
#  'BYD Auto is a manufacturer from China.': ['byd auto'],
#  'Thomas Pynchon published several short stories.': ['thomas pynchon'],
#  'Robin Thicke has worked with a mononymous singer.': ['robin thicke',
#   'brandy norwood',
#   'usher  musician '],
#  'Penny Dreadful aired on HBO.': ['penny dreadful  tv series '],
#  'Jon Huntsman Jr. served as United States Ambassador to Singapore from 1992 to 1993.': ['jon huntsman jr '],
#  "Matt Smith's last television role was as Jim Taylor.": ['matt smith  actor '],
#  'The Ultimates has been worked on by Mark Millar.': ['mark millar'],
#  'Pacific Rim received generally positive reviews.': ['pacific rim  film '],
#  'Tiger Woods plays sports professionally.': ['tiger woods'],
#  'Cape Fear stars an actor.': ['cape fear  1991 film ',
#   'gregory peck',
#   'cape fear  1991 film ',
#   'cape fear  1991 film ',
#   'robert de niro',
#   'cape fear  1991 film ',
#   'gregory peck'],
#  "Kitti's hog-nosed bat is the only extant member of a family.": ['kitti s hog nosed bat'],
#  "Arkham Asylum's patients are comprised of the Riddler.": ['arkham asylum'],
#  'Audrey Horne was introduced in a series that premiered in 1990.': ['audrey horne',
#   'twin peaks'],
#  'Paul Newman was an IndyCar driver.': ['paul newman',
#   'paul newman',
#   'paul newman'],
#  'Pablo Fenjves wrote for someone who wrote.': ['pablo fenjves',
#   'ghostwriter'],
#  'Mel Gibson played a lead role in a movie.': ['mel gibson',
#   'mad max  franchise '],
#  'There was a period of peace that the country of Lebanon experienced.': ['lebanon'],
#  'The Martian was directed by Adam Sandler.': ['the martian  film '],
#  'Andrew Stanton has worked on movies.': ['andrew stanton'],
#  'Joseph Stalin was made General Secretary in 1922.': ['joseph stalin'],
#  'Jared Leto was born December 26, 1971.': ['jared leto'],
#  'Event management is the application of project management.': ['event management',
#   'event management'],
#  'Kris Jenner is the aunt of Kourtney Kardashian.': ['kris jenner'],
#  'Over 75% of the Russian population live in European Russia.': ['russia'],
#  'James Bond is portrayed by Daniel Craig in the film Spectre.': ['james bond'],
#  'Me Before You is set in the UK.': ['me before you  film '],
#  'The Wonderful Wizard of Oz is where the Wicked Witch of the West made her debut.': ['wicked witch of the west'],
#  'Rope is a film.': ['rope  film ', 'rope  film '],
#  'Octopuses protect themselves against predators.': ['octopus'],
#  'Bulgaria saw conflicts with its neighbours.': ['bulgaria'],
#  'The Bridges of Madison County (film) was destroyed before it can be released.': ['the bridges of madison county  film '],
#  'John is the middle name of Donald Trump.': ['donald trump'],
#  'Neve Campbell had a starring role in seasons of House of Cards.': ['neve campbell'],
#  'Jesse Eisenberg starred in a film directed by Greg Mottola in 2009.': ['jesse eisenberg',
#   'adventureland  film '],
#  'Baahubali: The Beginning is a movie from India released in 2015.': ['baahubali colon  the beginning'],
#  'The Americans first aired on FX.': ['the americans  2013 tv series '],
#  'Mariah Carey is from America.': ['mariah carey'],
#  'Shahid Kapoor has only starred in Jumanji.': ['shahid kapoor'],
#  'Interstellar is an American science-fiction movie.': ['interstellar  film '],
#  "James Nesbitt was a star in Murphy's Law from 2001-2007.": ['james nesbitt'],
#  'Portia de Rossi won a Screen Actors Guild Award in 1999 for her role in Ally McBeal.': ['portia de rossi'],
#  'Ramzan Kadyrov established a tournament.': ['ramzan kadyrov'],
#  'Asia extends to places.': ['asia'],
#  'Agatha Christie was given the status of Dame for her literary contributions.': ['agatha christie'],
#  'Martin Scorsese worked on the pilot episode of Boardwalk Empire.': ['martin scorsese'],
#  'The Conjuring 2 was released in 2016.': ['the conjuring 2'],
#  'Elizabeth Meriwether is a television antenna.': ['elizabeth meriwether'],
#  'The Minnesota Vikings have lost all their Super Bowl games.': ['minnesota vikings'],
#  'Iron Man is based on the eponymous superhero.': ['iron man  2008 film '],
#  'The Thénardiers are in Les Miserables.': ['thénardiers'],
#  'Jay Sekulow is a lawyer.': ['jay sekulow',
#   'lawyer',
#   'jay sekulow',
#   'lawyer'],
#  'Keanu Reeves is a car.': ['keanu reeves'],
#  'Tom Felton did not act in From the Rough.': ['tom felton'],
#  'The Hermetic Order of the Golden Dawn was focused on the study of the occult.': ['hermetic order of the golden dawn'],
#  'Greece is a Jewish state.': ['christian state'],
#  'Mike Pence lost a US congressional election in 1988.': ['mike pence'],
#  'There is an album called Honeysuckle Rose by Willie Nelson.': ['willie nelson',
#   'honeysuckle rose  album '],
#  'Rio de Janeiro is in Brazil.': ['rio de janeiro'],
#  'John Cena has a career in a organization.': ['john cena', 'wwe'],
#  "The blue whale's body can be various shades of bluish-grey dorsally, and somewhat lighter underneath.": ['blue whale'],
#  'Saving Private Ryan is a portrayal of war.': ['saving private ryan'],
#  'Titanium was written by David Guetta and a team of uncredited writers.': ['titanium  song '],
#  'Kevin Durant is not a photographer.': ['kevin durant'],
#  'Fargo has executive producers.': ['fargo  tv series '],
#  'Bridget Moynahan tried to have a career in modeling.': ['bridget moynahan'],
#  'Bill Gates is the co-founder of Microsoft.': ['bill gates'],
#  "Role Models stars American actor Bobb'e J. Thompson.": ['role models',
#   'bobb e j  thompson'],
#  'Tom Hiddleston appeared in War Horse.': ['tom hiddleston',
#   'tom hiddleston',
#   'tom hiddleston',
#   'tom hiddleston'],
#  'James Garner played the leading male role in The Great Escape.': ['james garner'],
#  'LGBT is not an acronym containing the word transgender.': ['lgbt'],
#  'Lily Collins wrote the book Clary Fray.': ['lily collins'],
#  'Leyton Orient F.C. is in the ocean.': ['leyton orient f c '],
#  'George Foreman has been inducted into the World Boxing Hall of Fame.': ['george foreman',
#   'george foreman',
#   'george foreman'],
#  'Lily Collins attended University of Southern California.': ['lily collins'],
#  'South America is home to the Charles River.': ['south america',
#   'charles river'],
#  'Pregnancy can occur as a result of assisted reproductive technology.': ['pregnancy'],
#  'The Night Of was co-directed by James Marsh.': ['the night of'],
#  'Avatar was unconnected to James Cameron.': ['avatar  2009 film '],
#  'Minnesota was inhabited by native peoples of Canada and the northern United States.': ['minnesota',
#   'anishinaabe'],
#  'Maigret stars Rowan Atkinson.': ['rowan atkinson'],
#  "The Kitti's hog-nosed bat is capable of movement.": ['kitti s hog nosed bat'],
#  'Alice is a movie.': ['alice  1990 film '],
#  "Kaitlin Olson was a cast on It's Always Sunny in Philadelphia in 2005.": ['kaitlin olson'],
#  'Maggie Smith is an actress.': ['maggie smith'],
#  'American Gothic television show had an appearance from Evan Rachel Wood.': ['evan rachel wood'],
#  'William Shatner hosted a television series.': ['william shatner'],
#  'Barbados is not ranked as a leading tourist destination.': ['barbados'],
#  'Keanu Reeves has only worked as a chef.': ['keanu reeves'],
#  'Sean Combs was born in Harlem.': ['sean combs'],
#  'The Fisher King features Michael Jeter in a supporting role.': ['the fisher king'],
#  'Varun Dhawan has worked with people.': ['varun dhawan'],
#  'Cary Grant co-directed in the film The Philadelphia Story.': ['cary grant',
#   'the philadelphia story  film '],
#  'Muhammad was persecuted by some Meccan tribes.': ['muhammad',
#   'persecution of muslims by meccans'],
#  'Harry Styles has yet to ever act.': ['harry styles'],
#  'The Houston Rockets have won four Western Conference sandwiches.': ['houston rockets'],
#  'Nick Nolte was born in 1943.': ['nick nolte'],
#  'Stagira is an ancient city.': ['stagira  ancient city ',
#   'stagira  ancient city '],
#  'Tim Rice wrote Chess with Bjorn Ulvaeus.': ['tim rice'],
#  'Liev Schreiber became known.': ['liev schreiber'],
#  'Timon & Pumbaa is made by a company.': ['timon   pumbaa  tv series '],
#  'Glen Campbell is from America.': ['glen campbell'],
#  'Eddie Redmayne has always declined to act in spy films.': ['eddie redmayne',
#   'the good shepherd  film '],
#  'The Voice is a university class.': ['the voice  u s  tv series '],
#  'Neve Campbell has yet to work with Netflix.': ['neve campbell'],
#  'Good Will Hunting cast included Matt Damon.': ['good will hunting'],
#  'George H. W. Bush was president from 1889 to 1993.': ['george h  w  bush'],
#  'Chris Froome finished the 2011 Vuelta a España.': ['chris froome'],
#  'Taraji P. Henson starred in a movie.': ['taraji p  henson', 'hustle   flow'],
#  'Michelle Rodriguez is in the film industry.': ['michelle rodriguez'],
#  'Philadelphia contains 67 National Historic Landmarks.': ['philadelphia'],
#  'The Nilotic languages have speakers in South Sudan.': ['nilotic languages'],
#  'Yardie was published in 2001.': ['yardie  novel '],
#  'Ranbir Kapoor is the co-founder of a production company.': ['ranbir kapoor'],
#  'Sister Act is a TV show.': ['sister act'],
#  'Raoul Walsh directed The Big Trail.': ['the big trail'],
#  'Ringo Starr sang lead vocals on "Yellow Submarine".': ['ringo starr'],
#  'The Wolf of Wall Street got multiple nominations at the Academy Awards in 2014.': ['the wolf of wall street  2013 film ',
#   '86th academy awards'],
#  'Anastasia Steele is a main character in Fifty Shade of Grey.': ['fifty shades of grey'],
#  'Good Will Hunting stars Ben Affleck.': ['good will hunting'],
#  'The Resident Evil film series is loosely inspired by the game of the same name.': ['resident evil  film series '],
#  'Christopher Columbus worked for monarchs.': ['christopher columbus'],
#  'Jesse Eisenberg was employed with Ari Graynor.': ['jesse eisenberg',
#   'holy rollers  film '],
#  'Game of Thrones is a board game.': ['game of thrones'],
#  'Nicki Minaj grew up in the UK.': ['nicki minaj'],
#  'Mark Cuban is a person who invests.': ['mark cuban'],
#  'Sunrise created a co-production with a design studio formed in 1972 and it is Japanese.': ['sunrise  company ',
#   'studio nue'],
#  'Sepsis is more common among males than females as of 1988.': ['sepsis'],
#  'Dementia was an ailment of Al Capone.': ['al capone'],
#  'The Great Buck Howard is rarely American.': ['the great buck howard'],
#  'Bradley Cooper found great success with a black comedy crime film.': ['bradley cooper'],
#  'The United States is a superpower.': ['united states'],
#  'Lisbon is a city that is the capital of something.': ['lisbon'],
#  'Sylvester Stallone was nominated twice for the Academy Awards in 1977 for Rocky.': ['sylvester stallone'],
#  'Ryan Gosling earned a Golden Globe nomination for his role in Blue Valentine.': ['ryan gosling'],
#  'Vikram runs a welfare association.': ['vikram  actor '],
#  'Travis Barker has avoided drums completely.': ['travis barker'],
#  'David Beckham signed a contract with LA Galaxy.': ['david beckham',
#   'la galaxy'],
#  'Titus destroyed a city.': ['titus'],
#  'Jean-Claude Van Damme is a Belgian screenwriter.': ['jean claude van damme'],
#  'Anthony Meindl has worked with and coached Chace Crawford.': ['anthony meindl'],
#  'The Hangover Part III includes Ed Helms.': ['the hangover part iii'],
#  "Above the Law's alternative title is Nico.": ['above the law  film '],
#  'Tale of Tales is a film from 2015.': ['tale of tales  2015 film '],
#  'Buddhism is largely based on the lessons of Buddha.': ['buddhism'],
#  'Edward Norton has co-written on projects.': ['edward norton'],
#  'Emmanuel Adebayor died in the Togo national football team attack.': ['emmanuel adebayor'],
#  'The Council on Foreign Relations is a for-profit.': ['council on foreign relations',
#   'council on foreign relations'],
#  'Glee was nominated for Outstanding Original Music and Lyrics.': ['glee  season 6 '],
#  'Hugh Grant was a figure of 1990s British popular culture.': ['hugh grant'],
#  'Cougar Town was an American television sitcom that ended in 2016.': ['cougar town'],
#  'Joy was directed by David O. Russell.': ['joy  film '],
#  'George Martin refused to ever work in television.': ['george martin'],
#  'Bal Gangadhar Tilak died on August 1, 1820.': ['bal gangadhar tilak'],
#  'Detroit is the 21st-most populous city in the United States.': ['detroit'],
#  'Charlie Rubin did some writing for In Living Color.': ['charlie rubin'],
#  'London was at first a settlement named Londinium in the year 43.': ['london',
#   'londinium'],
#  'Saskatchewan is bordered on the east by a western province of Canada.': ['saskatchewan',
#   'manitoba'],
#  'Christianity extended to sub-Saharan Africa.': ['christianity'],
#  'The Great Debaters is a television show.': ['the great debaters'],
#  'Lust for Life was adapted only by Martin Scorsese.': ['lust for life  film '],
#  'There is a sport called tennis.': ['tennis'],
#  'Leonardo da Vinci has only ever been in Venice.': ['leonardo da vinci'],
#  'Ginger Baker was almost inducted into the Classic Drummer Hall of Fame.': ['ginger baker'],
#  'Juris Doctor is earned by completing law school in some common law countries.': ['juris doctor'],
#  'Hopman Cup has been attended by nobody.': ['hopman cup'],
#  'Indian is a comedy drama podcast.': ['indian  1996 film '],
#  'Laurence Olivier starred in an adaptation of Hamlet.': ['laurence olivier',
#   'hamlet  1948 film '],
#  'Dubai is located on the north coast of a sea in Eastern Asia.': ['dubai'],
#  'Jerry Seinfeld is only a comedian.': ['jerry seinfeld'],
#  'Jean-Martin Charcot was a neurologist.': ['jean martin charcot'],
#  'Steven Soderbergh directed something.': ['steven soderbergh'],
#  'Sanjay Gupta was rejected from the White House Fellows program.': ['sanjay gupta'],
#  'Bring It On (film) is a television show.': ['bring it on  film '],
#  'Hannibal was a military strategist.': ['hannibal'],
#  'Cage Warriors held an event in the most populous city of England.': ['cage warriors',
#   'london'],
#  'Bill Gates was chief software architect at Microsoft.': ['bill gates'],
#  'Michael Jackson was killed by Conrad Murray.': ['michael jackson'],
#  'Ellen Burstyn has yet to win any Emmy Awards.': ['ellen burstyn'],
#  'Atlantic City failed to cast Kate Reid.': ['atlantic city  1980 film '],
#  'Kurt Angle is not an American professional wrestler.': ['kurt angle'],
#  "Jennifer Aniston's net worth as of 2014 is estimated at 150 million.": ['jennifer aniston'],
#  'Dolly Parton starred in Rhinestone.': ['dolly parton'],
#  'Calvin Harris has more songs on the UK Singles Chart than Michael Jackson.': ['calvin harris'],
#  'Gayathri Raguram started out in a film.': ['gayathri raguram'],
#  'The Godfather Part III only stars male actors.': ['the godfather part iii',
#   'diane keaton'],
#  'Tom Hardy has appeared in three Christopher Nolan works.': ['tom hardy'],
#  'Michael Jackson was accused of child sexual abuse.': ['michael jackson'],
#  'The Hui people also have communities other regions of China.': ['hui people'],
#  'Sarrainodu translates to "The Wrong Person".': ['sarrainodu'],
#  'Ajab Prem Ki Ghazab Kahani is a film from India.': ['ajab prem ki ghazab kahani'],
#  'Kirk Douglas was born two years before December 9th, 1916.': ['kirk douglas'],
#  'Ryan Dusick is an American musician and producer.': ['ryan dusick'],
#  'Seven Days in May passed over Ava Gardner for a role in the cast.': ['seven days in may'],
#  'Love & Mercy (film) was unable to cast John Cusack.': ['love   mercy  film '],
#  'There is a band called Blink-182.': ['blink 182'],
#  'Adam Sandler is an actor.': ['adam sandler'],
#  'Papua New Guinea is dissociated with Oceania in every way.': ['papua new guinea'],
#  'David Hayter wrote X-Men (film).': ['x men  film '],
#  "The 84th Academy Awards' winners included The Iron Lady and The Descendants.": ['84th academy awards',
#   'the descendants',
#   'the iron lady  film '],
#  'Jack Black has been nominated for Golden Globe Awards.': ['jack black'],
#  'Michelle Williams began her career on television.': ['michelle williams  actress '],
#  'Jodie Foster played an FBI trainee looking into a murder case.': ['jodie foster'],
#  'In California, Little Miss Sunshine was filmed.': ['little miss sunshine'],
#  'Denmark is an absolute monarchy.': ['denmark'],
#  "Julius Caesar's office was also called dictator in perpetuum and he died.": ['julius caesar',
#   'dictator perpetuo'],
#  'Taylor Swift is not a singer-songwriter.': ['taylor swift'],
#  'John Constantine was originally a supporting character.': ['john constantine'],
#  "Aneurin Barnard's birth year is 1987.": ['aneurin barnard'],
#  'The 20th is the day Diana Rigg was born.': ['diana rigg'],
#  'Punk rock was made in the United States.': ['punk rock'],
#  'Geraldine Chaplin got a Golden Globe nomination.': ['geraldine chaplin'],
#  'Paranormal pertains to extrasensory perception.': ['paranormal'],
#  'Cindy McCain is the spouse of John McCain.': ['cindy mccain'],
#  'There is an episode of Futurama.': ['futurama'],
#  "One of Future's studio albums was published in 2017.": ['future  rapper ',
#   'future  future album '],
#  'Macbeth was written by William Shakespeare.': ['macbeth'],
#  "Arnold is Al Gore's middle name.": ['al gore'],
#  'British Fantasy Award categories include Best Novella and Best Short Story.': ['british fantasy award'],
#  'Pompeii is in Spain.': ['pompeii'],
#  "George W. Bush's brother ran for president of the United States.": ['george w  bush'],
# ...
#   'saturday night  magazine '],
#  'Elvis Presley never owned Graceland.': ['elvis presley', 'graceland'],
#  '10 Cloverfield Lane is a book in the Cloverfield franchise.': ['10 cloverfield lane'],
#  'Morgan Freeman appeared in Deep Impact.': ['morgan freeman'],
#  'The Godfather Part III was nominated for seven Academy Awards.': ['the godfather part iii'],
#  'Adam Driver was in the singing group Lincoln.': ['adam driver'],
#  'Jerry Goldsmith was denied any nominations for Academy Awards.': ['jerry goldsmith'],
#  'Xi Jinping joined the Politburo Standing Committee.': ['xi jinping'],
#  'Cindy McCain is chair of a big Anheuser-Busch distributor of beer.': ['cindy mccain'],
#  'There is an American film called Funny Girl (film).': ['funny girl  film '],
#  'Khal Drogo was introduced in 1796.': ['khal drogo'],
#  'Michelle Rodriguez has won an award.': ['michelle rodriguez'],
#  'Mexico is the least populous country in Latin America.': ['mexico'],
#  'Minnesota has a high standard of living.': ['minnesota'],
#  'Bela Lugosi was a horror film actor.': ['bela lugosi'],
#  'Billy Clanton was an only child.': ['billy clanton'],
#  'As the World Turns was replaced by an American talk show that debuted in the fall of 2010.': ['as the world turns',
#   'the talk  tv series '],
#  'Trevor Berbick died on October 29th, 2006.': ['trevor berbick'],
#  'Naruto is a manga written and illustrated by Masashi Kishimoto.': ['naruto'],
#  'Richmond, Virginia is a neighbor to the Federal Reserve Bank of Richmond.': ['richmond  virginia',
#   'richmond  virginia'],
#  'Some spider species are social and construct communal webs.': ['spider'],
#  "Reese Witherspoon's breakthrough role was in an adaptation of a novel.": ['reese witherspoon',
#   'legally blonde'],
#  'Alicia Silverstone was a star in a film directed by Amy Heckerling.': ['alicia silverstone',
#   'clueless  film '],
#  'Good Will Hunting is a political-drama.': ['good will hunting'],
#  'Justin Bieber has won things.': ['justin bieber'],
#  'Malcolm Young co-founded AC/DC in July 1973.': ['malcolm young'],
#  'Barbados is not considered part of the Caribbean.': ['barbados'],
#  'Oliver Reed was born in a month in 1938.': ['oliver reed'],
#  'Vincente Minnelli is American.': ['vincente minnelli'],
#  'Richard Nixon was involved in politics.': ['richard nixon'],
#  'J. K. Rowling had a child.': ['j  k  rowling'],
#  '42 (film) is a film that grossed over $97 million dollars.': ['42  film '],
#  'There is a professional golfer name Tiger Woods.': ['tiger woods'],
#  'Paul Wesley is the professional alias of Paul Tomasz Wasilewski.': ['paul wesley'],
#  'Twenty One Pilots is a musical group.': ['twenty one pilots',
#   'twenty one pilots'],
#  "Spotlight was released in the 2010's.": ['spotlight  film '],
#  'The memory of Titanic is kept alive in different works.': ['rms titanic',
#   'rms titanic'],
#  'Bob Arum is only the founder of a professional soccer company.': ['bob arum'],
#  "Giacomo Casanova's birth month is April.": ['giacomo casanova'],
#  'Jeff Bezos was born in January of 1964.': ['jeff bezos'],
#  'There is a character named Fred in Scooby-Doo.': ['scooby doo'],
#  'Hotel Hell is broadcast on Fox.': ['hotel hell'],
#  'Haitian Creole is French-based and it is an important language.': ['haitian creole'],
#  'Jerry Seinfeld was in the sitcom Seinfeld, which he also created and wrote.': ['jerry seinfeld'],
#  'The Incredible Hulk is a motion picture.': ['the incredible hulk  film '],
#  'IBM invented a multi-purpose electronic computer intended for individual use.': ['ibm',
#   'personal computer'],
#  'Up All Night was released by Syco Records in 2011.': ['up all night  one direction album '],
#  'Sammy Cahn died in the 90s.': ['sammy cahn'],
#  'The screenplay for the film Logan (film) was co-written by James Mangold.': ['logan  film '],
#  'The Beach Boys is a group.': ['the beach boys', 'the beach boys'],
#  'Gimli is from Middle-earth.': ['gimli  middle earth '],
#  'Year Zero is a single.': ['year zero  album '],
#  'Howard Stern developed his on show from 1976 to 1982.': ['howard stern'],
#  'The Magna Carta was typically renewed by each British monarch.': ['magna carta'],
#  'A reflex is made possible by neural pathways that act on an impulse before it reaches the brain.': ['reflex'],
#  'Nepal is 21 kilometers away from Bangladesh.': ['nepal'],
#  'Aishwarya Rai appeared in Raincoat.': ['aishwarya rai'],
#  'Amy Adams played Margaret Keane in Big Eyes (2014).': ['amy adams'],
#  'Nicki Minaj wrote and sang the song Super Bass.': ['nicki minaj',
#   'super bass'],
#  "Beauty Shop's character Gina was originally presented in Barbershop 2: Back in Business.": ['beauty shop'],
#  'Game of Thrones had Diana Rigg nominated for an award.': ['game of thrones'],
#  'Contained in the Bible are narratives.': ['bible'],
#  'The Amanda Show was the second TV show created by Dan Schneider.': ['the amanda show',
#   'dan schneider  tv producer '],
#  'Travis Scott is an American citizen.': ['travis scott'],
#  'American Horror Story: Hotel premiered on October 7, 2015.': ['american horror story colon  hotel'],
#  'Planet of the Apes (1968 film) was written by someone from America.': ['planet of the apes  1968 film ',
#   'michael wilson  writer ',
#   'rod serling'],
#  'Andhra Pradesh is an Indian restaurant.': ['andhra pradesh'],
#  'Portal 2 was released for a platform.': ['portal 2', 'steam  software '],
#  'Malaysia Airlines started a plan.': ['malaysia airlines'],
#  'Rhona Mitra is from England.': ['rhona mitra'],
#  'A movie in 1969 featured Oliver Reed.': ['oliver reed', 'hannibal brooks'],
#  'Tamera Mowry is in Sister, Sister.': ['tamera mowry'],
#  'Cricket has batsmen.': ['cricket'],
#  'Leigh Steinberg was a consultant on Jerry Maguire.': ['jerry maguire'],
#  'Red Velvet (band) is a girl group.': ['red velvet  band '],
#  'Born Naked was concocted by a singer-songwriter.': ['born naked', 'rupaul'],
#  "In the 1990's Salman Khan worked in Bollywood.": ['salman khan'],
#  'My Sweet Lord is an album.': ['my sweet lord'],
#  'John Lennon was in the most commercially successful band in history.': ['john lennon'],
#  'Spider-Man is a horror movie franchise.': ['spider man'],
#  "Kevin Brodbin was a writer of Constantine's screenplay.": ['constantine  film '],
#  'Anaconda is on the third studio album by Nicki Minaj.': ['anaconda  nicki minaj song '],
#  'Eagles (band) made an album called Their Greatest Hits (1971 -- 1975) that was ranked among the 20 best-selling albums in the United States.': ['eagles  band '],
#  'San Junipero is not from Britain.': ['san junipero'],
#  'Morgan Freeman was an actor in The Shawshank Redemption.': ['morgan freeman',
#   'the shawshank redemption'],
#  'Horrible Bosses is an Ecuadorian film.': ['horrible bosses'],
#  'Robert Redford guest starred on The Untouchables.': ['robert redford'],
#  'The Germanic peoples are of Southern Canadian origin.': ['germanic peoples',
#   'germanic peoples'],
#  'Brittany Murphy was born in Texas.': ['brittany murphy'],
#  'The Boys from Brazil features Uta Hagen.': ['the boys from brazil  film '],
#  'Get Out stars Brad Pitt.': ['get out  film ',
#   'get out  film ',
#   'get out  film ',
#   'get out  film '],
#  'Alpha Centauri can be abbreviated as Alpha Cen.': ['alpha centauri'],
#  'R. Madhavan was in the cast of the drama film Rang De Basanti.': ['r  madhavan'],
#  'Walt Whitman volunteered during a war that was in a country.': ['walt whitman',
#   'american civil war'],
#  'Shawn Mendes and Island Records signed a deal.': ['shawn mendes'],
#  'Negan is a fictional character in The Walking Dead.': ['negan'],
#  'Stanley Kubrick worked on Dr. Strangelove.': ['stanley kubrick'],
#  'Furia is written by anyone except Gregory Levasseur.': ['furia  film '],
#  'Count Basie formed a group.': ['count basie'],
#  'Tupac Shakur was born Lesane Parish Crooks.': ['tupac shakur'],
#  'Gerard Lee was born in the 1950s.': ['gerard lee'],
#  'North Vancouver is served by the North Vancouver Fire Department.': ['north vancouver  district municipality '],
#  'Carrie Fisher was a script doctor.': ['carrie fisher'],
#  'Gwen Stefani was in a band.': ['gwen stefani', 'gwen stefani'],
#  'Water has an effect on the texture of Vitamin B-12.': ['vitamin b12'],
#  'Bruce Springsteen received no honors or awards.': ['bruce springsteen'],
#  'Papua New Guinea is an Oceanian country.': ['papua new guinea'],
#  'Bam Margera is a professional skateboarder.': ['bam margera'],
#  'Steve Buscemi was a cast member in a film.': ['steve buscemi'],
#  'Jackie Robinson died in 1972.': ['jackie robinson'],
#  'Tall Story is a North American film.': ['tall story'],
#  "Sofia Coppola's father is Abraham Lincoln.": ['sofia coppola'],
#  'David Tennant got the National Television Award for Special Recognition.': ['david tennant'],
#  'Carey Taylor did not join Slipknot in 1997.': ['corey taylor'],
#  "Heartlight is the first track on Diamond's 1982 album.": ['heartlight  song '],
#  'Justin Timberlake is a record producer.': ['justin timberlake'],
#  'R. Kelly has only sold over 10 million records worldwide.': ['r  kelly'],
#  "Ryan O'Neal acts professionally.": ['ryan o neal'],
#  'George Lucas created the Star Wars franchise.': ['george lucas'],
#  'Adderall affects control.': ['adderall'],
#  "The University of Oxford operates the world's oldest university museum.": ['university of oxford'],
#  'Derrick Rose does not play for the New York Knicks.': ['derrick rose'],
#  'Islam had a prophet.': ['islam'],
#  'Tiger Woods is a sports player.': ['tiger woods'],
#  'Nepal has a population.': ['nepal'],
#  'The Fate of the Furious premiered in Berlin.': ['the fate of the furious'],
#  'Kristen Stewart has avoided the acting profession entirely.': ['kristen stewart'],
#  'Charles Marie de La Condamine was born in January 1701.': ['charles marie de la condamine'],
#  'Agatha Christie avoided professional writing her entire life.': ['agatha christie'],
#  'Yale School of Drama provided training in acting.': ['yale school of drama'],
#  'Laurence Fishburne acted in a work.': ['laurence fishburne'],
#  'In 1918, Azerbaijan proclaimed its independence.': ['azerbaijan'],
#  'Selene serves as a character.': ['selene  underworld '],
#  'The Champ stars Ricky Schroder in the lead role.': ['the champ  1979 film '],
#  'John Stewart is a fictional person with super powers.': ['john stewart  comics ',
#   'superhero'],
#  'Steven Gerrard represented his country at fifty FIFA World Cups.': ['steven gerrard'],
#  'James Nesbitt starred in at least one television series.': ['james nesbitt'],
#  'Odin is accompanied by animal companions.': ['odin'],
#  'Steven Tyler is a former television music competition judge.': ['steven tyler'],
#  'The Rolling Stones are a English rock band.': ['the rolling stones'],
#  'Aishwarya Rai was in several television commercials.': ['aishwarya rai'],
#  'Randy Orton was born on April 1.': ['randy orton'],
#  'WeChat is a German application.': ['wechat'],
#  'Patrick Cutrone is a person.': ['patrick cutrone'],
#  'Sue Vertue was born in September.': ['sue vertue'],
#  "God in Islam's theology is all-powerful and all-knowing.": ['god in islam'],
#  'Zeus is the last of his siblings to be born.': ['zeus'],
#  'Deadpool 2 featured Ryan Reynolds, Morena Baccarin, Ed Skrein, T. J. Miller, Gina Carano, Leslie Uggams, Brianna Hildebrand, and Stefan Kapičić.': ['deadpool  film ',
#   'deadpool  film ',
#   'deadpool  film '],
#  'Fifty Shades of Grey is a romance novel.': ['fifty shades of grey'],
#  'Gone Girl lacks a performance by Neil Patrick Harris.': ['gone girl  film '],
#  'Liverpool F.C. was the ninth highest-earning football club in the world for 2014-2015.': ['liverpool f c '],
#  'Buddy Holly played in Lubbock.': ['buddy holly'],
#  'Cosmetics commonly include hair gel.': ['cosmetics'],
#  'Wallander is a series.': ['wallander  uk tv series '],
#  'George A. Romero worked on the horror movie The Crazies.': ['george a  romero',
#   'the crazies  1973 film '],
#  'Patrick Bateman works as an investment banker.': ['patrick bateman'],
#  'Love & Mercy (film) was unable to cast Elizabeth Banks.': ['love   mercy  film '],
#  "Since 2000, Luxembourg's Grand Duke has been Henri.": ['luxembourg',
#   'henri  grand duke of luxembourg'],
#  'Brian Lynch was the beginning writer for Angel: After the Fall.': ['brian lynch  writer '],
#  'Serena Williams is a golf player.': ['serena williams'],
#  'Coldplay released The Blue Room in 1995.': ['coldplay'],
#  "Alison Brie's full name is Alison Brie Lewis.": ['alison brie'],
#  'Tequila is an arbitrary name.': ['tequila'],
#  'The Jim Crow laws mandated segregation.': ['jim crow laws'],
#  'Saswata Chatterjee refuses to work in television.': ['saswata chatterjee'],
#  'North Korea is bordered.': ['north korea',
#   'north korea',
#   'north korea',
#   'north korea'],
#  'Iris Murdoch refused to engage in philosophy.': ['iris murdoch'],
#  'Kristen Bell has appeared on television.': ['kristen bell', 'veronica mars'],
#  'Laurie Hernandez was conceived on June 9th, 2000.': ['laurie hernandez'],
#  'The Democratic Republic of the Congo is a video game.': ['democratic republic of the congo'],
#  'Mauritius was a French embassy.': ['mauritius'],
#  'Leyton Orient F.C. is a club.': ['leyton orient f c ', 'leyton orient f c '],
#  'Collision Course is a single song.': ['collision course  album '],
#  'Kris Kristofferson collaborated with Nashville songwriters.': ['kris kristofferson'],
#  'Little Miss Sunshine had a wider release on August 18.': ['little miss sunshine'],
#  "Birth of the Dragon's principal photography began in a city.": ['birth of the dragon',
#   'vancouver'],
#  'Emily Browning starred in Something in the Air.': ['emily browning'],
#  'Angela Lansbury is from Germany.': ['angela lansbury'],
#  'Larry Junstrom is American.': ['larry junstrom'],
#  'Kristen Bell was in a movie.': ['kristen bell',
#   'kristen bell',
#   'kristen bell',
#   'veronica mars  film '],
#  'The Existence of God has been argued by René Descartes.': ['existence of god'],
#  'Adam DeVine was involved in voice acting in animation films.': ['adam devine'],
#  'Star Wars is centered on a film series.': ['star wars'],
#  'Daniela Hantuchová beat a tennis player.': ['daniela hantuchová',
#   'martina hingis'],
#  'Baloo was featured in The Jungle Book.': ['baloo'],
#  'Minnesota was inhabited by the native Ojibwe/Anishinaabe.': ['minnesota',
#   'anishinaabe',
#   'ojibwe'],
#  'Shonen Jump is banned in North America.': ['shonen jump  magazine '],
#  'Samantha Robson was born in 1966.': ['samantha robson'],
#  'Alandi is in the state of New Jersey.': ['alandi'],
#  'Ayn Rand was an advocate for free and open trade between private citizens without governmental interference.': ['ayn rand',
#   'laissez faire'],
#  'No one died from lymphoma in 2012.': ['lymphoma'],
#  'Thinkin Bout You was nominated for Record of the Year in 2013.': ['thinkin bout you'],
#  "Faith Evans's fifth album is called Thriller.": ['faith evans'],
#  'Heinrich Himmler never held a position in the Nazi Party.': ['heinrich himmler'],
#  'Alec Baldwin co-starred in 30 Rock.': ['30 rock', 'alec baldwin'],
#  'Everybody Needs a Best Friend was composed by a person.': ['everybody needs a best friend',
#   'walter murphy'],
#  'Emily Ratajkowski was the leading role in We Are Your Friends in 2015.': ['emily ratajkowski'],
#  'Marlon Brando was in a film in 1953.': ['marlon brando', 'the wild one'],
#  'The 2017 Open Championship is a July golf championship.': ['2017 open championship'],
#  'Little Boy was dropped on the city of Boston.': ['little boy'],
#  'Harry Styles and his bandmates released the single Take Me Home.': ['harry styles'],
#  'Roger Federer held the award from Laureus.': ['roger federer'],
#  'Divergent was released on DVD.': ['divergent  film '],
#  'Eric Singer has done a performance with Lita Ford.': ['eric singer'],
#  'La La Anthony was a 2016 movie.': ['la la anthony'],
#  'Fantastic Beasts and Where to Find Them premiered in New York City.': ['fantastic beasts and where to find them  film ',
#   'fantastic beasts and where to find them  film '],
#  'Pirates of the Caribbean is set on the back of a fictional turtle.': ['pirates of the caribbean  film series '],
#  ...}

# %%
claims
# Out:
# ['Nikolaj Coster-Waldau worked with the Fox Broadcasting Company.',
#  'Nikolaj Coster-Waldau worked with the Fox Broadcasting Company.',
#  'Roman Atwood is a content creator.',
#  'History of art includes architecture, dance, sculpture, music, painting, poetry literature, theatre, narrative, film, photography and graphic arts.',
#  'Adrienne Bailon is an accountant.',
#  'Homeland is an American television spy thriller based on the Israeli television series Prisoners of War.',
#  'Homeland is an American television spy thriller based on the Israeli television series Prisoners of War.',
#  'The Boston Celtics play their home games at TD Garden.',
#  'The Ten Commandments is an epic film.',
#  'Tetris has sold millions of physical copies.',
#  'Cyndi Lauper won the Best New Artist award at the 27th Grammy Awards in 1985.',
#  'There is a movie called The Hunger Games.',
#  'Ryan Gosling has been to a country in Africa.',
#  'Ryan Gosling has been to a country in Africa.',
#  'Stranger Things is set in Bloomington, Indiana.',
#  'Ryan Seacrest is a person.',
#  'Puerto Rico is not an unincorporated territory of the United States.',
#  'Michael Giacchino composed the score for Doctor Strange.',
#  'Stranger than Fiction is a film.',
#  'Chris Hemsworth appeared in A Perfect Getaway.',
#  'Selena recorded music.',
#  "Robert J. O'Neill was born April 10, 1976.",
#  'The Silence of the Lambs was a film starring Scott Glenn.',
#  'Peggy Sue Got Married is a Egyptian film released in 1986.',
#  'Peggy Sue Got Married is a Egyptian film released in 1986.',
#  'Andy Roddick lost 5 Master Series between 2002 and 2010.',
#  'As the Vietnam War raged in 1969, Yoko Ono and her husband John Lennon did not have two week-long Bed-Ins for Peace.',
#  'Tupac Shakur was born Lesane Parish Crooks.',
#  'The Jim Henson Company produced The Muppet Movie, The Dark Crystal, and Labyrinth.',
#  'Slovenia uses the euro.',
#  'Slovenia uses the euro.',
#  'Iowa is a part of the Midwestern United States.',
#  'Saratoga is an American film from 1937.',
#  'J. Howard Marshall was a baby.',
#  'J. Howard Marshall was a baby.',
#  'Grace Jones is a dancer.',
#  'Lisbon has a population larger than 1.',
#  'Willie Nelson dropped out of college after three years.',
#  'Malcolm Young was the co-founder of Australian hard rock band AC/DC.',
#  'Newfoundland and Labrador is the most linguistically homogeneous of Canada.',
#  'Furia is adapted from a short story by Anna Politkovskaya.',
#  'One state of the United States has Russia to its west.',
#  'Sophie Turner was born in the 1990s.',
#  'Mother Teresa was made a saint by the church.',
#  'The Smurfs (film) was released.',
#  "C. S. Forester's first name was Carl.",
#  'Kong: Skull Island is a book.',
#  'The Challenge was a scripted show.',
#  'Berlin is the capital of Germany.',
#  'South Korea has a highly educated workforce.',
#  'Hacksaw Ridge came out in America on November 4, 2016.',
#  'Michael Fassbender is an actor.',
#  'Red Headed Stranger is a movie.',
#  'Paul Bettany has played Vision in at least two works.',
#  "Scotland's Hebrides is widespread and diverse with many islands.",
#  "Scotland's Hebrides is widespread and diverse with many islands.",
#  'Uzbekistan is a part of the Commonwealth of Independent States (CIS).',
#  'Charles, Prince of Wales is patron of numerous other organizations.',
#  'Chester Bennington is not a singer.',
#  'Vincent Cassel played Jacques Mesrine in at least two films.',
#  'Pope John Paul II co-stars many actors besides Christopher Lee.',
#  'David Beckham has zero middle names.',
#  'Indiana Jones has only been portrayed by Harrison Ford.',
#  'Brian Wilson was part of the Beach Boys.',
#  'The Great Gatsby centers on a youthful person with over a million dollars.',
#  'Shane Black and Chris Miller wrote Iron Man 3.',
#  'La La Anthony was conceived on June 25th, 1979.',
#  'Led Zeppelin is a band.',
#  'Richard Harris was born on October 25, 2002.',
#  'The Fosters is a television series.',
#  "Blair is Jonathan Hensleigh's middle name.",
#  'Filmfare is about cheese.',
#  'Buckingham Palace lacks brightly colored scagliola.',
#  'Sarah Paulson makes an appearance in What Women Want.',
#  'David Harbour is an American.',
#  'The terrain of Kazakhstan includes taiga.',
#  'José María Chacón surrendered the island of Trinidad in 1797, one year before his death.',
#  'Liverpool F.C. was valued at $1.55 billion at one point.',
#  'Land Rover makes cars.',
#  'Sully is a form of media.',
#  'Stanley Tucci performed in an television series.',
#  'Stanley Tucci performed in an television series.',
#  'Brock Lesnar married Randy Couture.',
#  'The Khmer Empire was not weak.',
#  'On the Road (film) premiered at a film festival.',
#  "Paramore's co-founders left the band in March 2010.",
#  'Peter Davison has been in a BBC show.',
#  '21 Jump Street was released June 16, 2012.',
#  'The collections of the Philadelphia Museum of Art contain over 240,000 objects.',
#  'Dustin Hoffman is an award-winning actor.',
#  'T. J. Miller was featured in Deadpool 2.',
#  'Stephon Marbury plays basketball in America.',
#  'CP affects people.',
#  'Alfred Hitchcock is a person.',
#  'Julius Caesar is only a book.',
#  'Pulp Fiction is directed by a male.',
#  'Pulp Fiction is directed by a male.',
#  'Absolute Beginners was directed by Hitchcock.',
#  'No Reservations got a mixed reception from critics.',
#  'Claire Danes is wedded to an actor from England.',
#  'Claire Danes is wedded to an actor from England.',
#  "Dangerous Liaisons is based on Christopher Hampton's novel.",
#  'The Academy Awards are an annual event.',
#  'The Academy Awards are an annual event.',
#  'Hubert Humphrey became the DFL candidate for mayor of a city.',
#  'Hubert Humphrey became the DFL candidate for mayor of a city.',
#  'Alex Rodriguez has 666 home runs.',
#  'Friendship has been studied in academic fields.',
#  'Judd Apatow is a person who writes.',
#  'Massachusetts is far away from Rhode Island.',
#  'Giancarlo Stanton was in the 2017 MLB draft.',
#  'Chris Pine appeared in Wonder Woman (2017 film).',
#  'Trevor Noah hosts a news satire show.',
#  'Lucas starred an actor that died on March 10.',
#  'Lucas starred an actor that died on March 10.',
#  'Ryan Phillippe refused to perform in the soap opera One Life to Live.',
#  'Sean Connery never won an Academy Award.',
#  'Venom has since become less of an antihero.',
#  'Overwatch is a video game in which players gain cosmetic awards and it assigns players into two teams of six, each player with a style of play known as Offense, Defense, Tank, and Support.',
#  'Lily James has been on TV.',
#  'Jing Tian date of birth is in July.',
#  "Jennifer Aniston's parents are Fred and Wilma Flintstone.",
#  'The Peloponnesian War was won by Sparta.',
#  'Isis had a temple at Behbeit El Hagar.',
#  'International Relations only includes the entertainment industry.',
#  'Régine Chassagne is Canadian.',
#  'John McCain works in politics.',
#  'Farrah Fawcett received an Emmy Award nomination for her role as a battered wife in the 1984 film The Burning Bed.',
#  'The Who\'s first single was "My Generation".',
#  'Planet of the Apes (1968 film) had a script that underwent rewrites.',
#  'Star vs. the Forces of Evil is a series.',
#  'Galaxy Quest is a movie that is American.',
#  'Friends with Benefits features actors.',
#  'Glenn Close won the Tony Award for Best Actress in a Play in 1984.',
#  'Glenn Close won the Tony Award for Best Actress in a Play in 1984.',
#  'Zooey Deschanel performed.',
#  'Seven Days in May stars an American.',
#  'Seven Days in May stars an American.',
#  'Seven Days in May stars an American.',
#  'Seven Days in May stars an American.',
#  'Winnipeg is home to several sports teams.',
#  'Mark Zuckerberg co-founded a website.',
#  'Mark Zuckerberg co-founded a website.',
#  'Rick and Morty was renewed for a fourth season in 2014.',
#  'Paul Walker acted in movies.',
#  'Clint Eastwood was nominated for an award.',
#  'Shonen Jump is published in a continent.',
#  'Shonen Jump is published in a continent.',
#  'Gilmore Girls is a Canadian show.',
#  'Honest sold 53,000 units in a week.',
#  'Since July 2012, Pranab Mukherjee has been in office.',
#  'Anonymous represents 4chan users simultaneously existing as an anarchic, digitized global brain.',
#  'San Francisco is in California.',
#  'Laadla is exclusively an American film.',
#  'Lily Collins wrote for a U.S magazine that targets teen girls.',
#  'Bangladesh has been affected by poverty.',
#  'Lisa Lopes was a founding member of TLC.',
#  'Lisa Lopes was a founding member of TLC.',
#  'The Formula (1980 film) was directed by an American.',
#  'The Formula (1980 film) was directed by an American.',
#  "Janet Jackson's third album was released in February 1986.",
#  "Transformers: The Last Knight's cast includes Tyrese Gibson.",
#  'There are two television series Morena Baccarin was part of.',
#  'There are two television series Morena Baccarin was part of.',
#  'There are two television series Morena Baccarin was part of.',
#  'There are two television series Morena Baccarin was part of.',
#  'Naturi Naughton was born in the year of 1984.',
#  'Paul Pogba has won four nonconsecutive Serie A titles.',
#  "Mel Gibson's name is Mel Colmcille Gerard Gibson.",
#  'WALL-E is a Golden Globe Award winner.',
#  'Generation X has no precise date for its cohort.',
#  'Islam is incapable of being a religion.',
#  'Jackie Chan has released an album.',
#  'Estimates of the number of species on Earth today vary widely, and most of those species have not been described.',
#  'Larry Junstrom is an American citizen.',
#  'Canada possesses a constitution.',
#  'Canada possesses a constitution.',
#  'Sophie Turner acted in The Thirteenth Tale.',
#  'The Renaissance is known for its cultural developments.',
#  'Pluto is not relatively small.',
#  'Steve Buscemi has appeared in many films by the Coen Brothers, such as Fargo.',
#  'Tyler Joseph is an ex-member of Twenty One Pilots.',
#  'Selena Gomez has more followers than anyone else in the world.',
#  'Big Boi is only a member of Norwegian metal bands.',
#  'Big Boi is only a member of Norwegian metal bands.',
#  "Priyanka Chopra was born in the 1900's.",
#  'Chris Pérez is a songwriter.',
#  'On March 27, 1963, Quentin Tarantino was born.',
#  'Tate Ellington appeared in Quantico.',
#  'Mr. Sunshine is from the Northern Hemisphere.',
#  "Dolly Parton isn't an actress.",
#  'The Amanda Show was the first female-created show on Nickelodeon.',
#  'The 19th G7 summit only included Russia.',
#  'Ethiopia has bodies of water can be described as rivers.',
#  'Ted Kaczynski grew up in Texas.',
#  'Keith Urban has put out no fewer than nine studio records.',
#  'Eminem has an album.',
#  'The Connaught Tunnel was lined only with mud and sand.',
#  'Jennifer Aniston is not a businesswoman.',
#  'Ilkhanate only contained Haiti.',
#  'Homeland is based on the classic BBC series Til Death Do Us Part.',
#  'True Blood is a science-fiction television series.',
#  'Jordan Knight is the lead singer of a band.',
#  'Adam Driver has had supporting roles.',
#  'Thor: The Dark World is a movie.',
#  'Loki is the male sibling of Helblindi and Byleistr.',
#  'Vincent van Gogh is from Amsterdam.',
#  'Chester Bennington is a person.',
#  'Inspectah Deck is stateless.',
#  'Tender Mercies is a drama from America.',
#  'Cristiano Ronaldo was a professional athlete.',
#  'Paul Simon is a person.',
#  'Baby Driver starred Eiza González.',
#  'David Dhawan is a film director.',
#  'The Challenge was a reality game show.',
#  "Rumi's influence transcends ethnic divisions.",
#  'Swedish Empire was ruled by Gustavus Adolphus from 1611 to 1632.',
#  'Swedish Empire was ruled by Gustavus Adolphus from 1611 to 1632.',
#  'Her was given a wide release on January 10, 2014.',
#  "Las Vegas's population has grown.",
#  'One type of spread is Vegemite.',
#  'The Divergent film series was worked on by Octavia Spencer.',
#  'Ramayanam was produced by M. S. Reddy and directed by Gunasekhar.',
#  'Man of Steel features the DC Comics character Superman.',
#  'Leukemia has to do with a lack of normal blood cells.',
#  'Judy Garland did not appear in a courtroom drama film.',
#  'Judy Garland did not appear in a courtroom drama film.',
#  'Until Dawn is a game.',
#  'Timothy Olyphant was born.',
#  'Telangana contains the city Warangal.',
#  'Bonnie Hunt narrated Cheaper by the Dozen.',
#  'The Levant was ruled by the House of Lusignan.',
#  'The Ten Commandments influence multiple religions.',
#  'The Hangover Part III includes Bradley Cooper, Ed Helms, Zach Galifianakis, Justin Bartha, and Ken Jeong, Jeffrey Tambor, Heather Graham, Mike Epps, Melissa McCarthy and John Goodman.',
#  "Ariana Grande's second album debuted at number one in the United States when it was released in 2014.",
#  'Ted Bundy committed assaults in the seventies.',
#  'Chinese people only can be associated with Spain through nationality.',
#  "Schindler's List was released in 1993.",
#  'Zeus is an angel.',
#  'Zeus is an angel.',
#  'Escape from Planet Earth is an American film.',
#  'Venus Williams has won multiple Wimbledons.',
#  'Quentin Tarantino directed a creative work.',
#  'The Beatles had Stuart Sutcliffe initially serve as their agent.',
#  '50 First Dates has no comedic elements.',
#  'A Nightmare on Elm Street was directed by Craven.',
#  'Charlize Theron acted in The Burning Plain.',
#  'Charlize Theron acted in The Burning Plain.',
#  'International Relations includes communication.',
#  'Jemaine Clement refuses to have anything to do with comedy.',
#  'Usain Bolt has competed in a sprint race in track and field in world competitions.',
#  'The main successor to the internet was the ARPANET.',
#  'Sarrainodu is an action movie.',
#  'Jawbreaker (film) stars an Italian-born American actress, film producer, director and singer.',
#  'Jawbreaker (film) stars an Italian-born American actress, film producer, director and singer.',
#  'Kurt Sutter is the creator of Sons of Anarchy.',
#  'La La Anthony has a middle name.',
#  'Lisa Marie Presley is an American singer.',
#  'Kingdom Hearts III is owned by Boyz II Men.',
#  'Kingdom Hearts III is owned by Boyz II Men.',
#  'Keanu Reeves is a film actor.',
#  'Dwayne Johnson won the WWF Intercontinental Championship twice.',
#  'Heartland is a canadian TV series.',
#  'By the metrics of the RIAA, The Beatles have sold more than any recording artist in America.',
#  'The national tree of Bangladesh is the mango.',
#  'There are two major contemporary political parties, and William Jennings Bryan belongs to one of them.',
#  'There are two major contemporary political parties, and William Jennings Bryan belongs to one of them.',
#  'Iris Murdoch was a writer.',
#  'David Koepp is a director.',
#  'A block is also called a "swat."',
#  'Paul Pogba made it to the 2015 UEFA Champions League Final with the Juventus team.',
#  'Leroy Jethro Gibbs is a character on the NFL series NCIS.',
#  'Leslie Howard was an actor.',
#  'Catching Fire is written.',
#  'Avatar: The Last Airbender aired on Nickelodeon.',
#  "Harry Hopman's widow has attended Hopman Cup.",
#  "Frank Zappa's debut was Freak Out!",
#  'Ruth Negga only acts in Irish cinema.',
#  'Ruth Negga only acts in Irish cinema.',
#  'George VI was succeeded by Mary I.',
#  'Psychological findings link to research and perspectives from an academic discipline.',
#  'Psychological findings link to research and perspectives from an academic discipline.',
#  'The Beach Boys was an American rock band.',
#  'Billy Bob Thornton directed a movie.',
#  'The Ren & Stimpy Show premiered on August 11, 1991.',
#  'Courteney Cox has always refused to play Gale Weathers.',
#  'Ronin is a film.',
#  'Abraham Lincoln had at least one rival.',
#  'There is a producer named Fred Savage.',
#  'Al Capone had neurosyphilis.',
#  'Al Capone had neurosyphilis.',
#  'Boston is located in the state of Massachusetts on the Shawmut Peninsula.',
#  'Boston is located in the state of Massachusetts on the Shawmut Peninsula.',
#  'Interstellar is a narrative in a visual medium.',
#  'Britney Spears titled her fourth studio album Britney.',
#  'Mike Tyson boxed.',
#  'The Hermetic Order of the Golden Dawn was uninterested in the study of the occult.',
#  'Ellen Burstyn has yet to be nominated for the Emmy Awards.',
#  'Princess Agents is a series on television.',
#  'Gwen Stefani works as a singer.',
#  'James Marsden worked with a director.',
#  'James Marsden worked with a director.',
#  'Carrie Fisher died of cardiac arrest.',
#  'Ice hockey has competitions.',
#  'The Fifth Element was the lowest-grossing French film in the international box office until 2011.',
#  'The Hunger Games is the first in Lord of the Rings series.',
#  'Audi used to have the pet "Truth in Engineering."',
#  'Java contains more than half of the population of Indonesia.',
#  'Urilla Sutherland Earp was the first spouse of Wyatt Earp.',
#  'Brave is a 2010s film.',
#  'Winter Passing had mixed reviews in 2005.',
#  'Audrey Horne was introduced in anything except a series that premiered on Sunday.',
#  'Audrey Horne was introduced in anything except a series that premiered on Sunday.',
#  'Line of Duty is a TV series.',
#  'The Dayton Agreement was signed in April.',
#  'The National Security Agency is tasked with the processing of data for counterintelligence purposes.',
#  'Gold is resistant to all acids except aqua regia.',
#  'There is a geologic period that spans 43 million years called Paleogene.',
#  'Cher has sold more than 100 million music records worldwide.',
#  'Bernard Madoff got the sentence.',
#  'Donkey is a fast-talking donkey.',
#  'O. J. Simpson received a criminal charge for armed robbery.',
#  'Ketogenic diet has protein.',
#  'Dennis Quaid refused to ever be an actor.',
#  'The United States was the first country to develop nuclear weapons.',
#  'Thandie Newton is incapable of appearing in British films.',
#  "Reese Witherspoon's breakthrough role was in a film.",
#  'Jenni Rivera was only nominated for an award presented annually by American network Univision.',
#  'Jenni Rivera was only nominated for an award presented annually by American network Univision.',
#  'Curly Top was released.',
#  'Edgar Allan Poe was a horse.',
#  'Danny DeVito received an Academy Award nomination.',
#  'PageRank was named after someone.',
#  'Morena Baccarin received a nomination.',
#  'Jeffrey Dahmer committed murders in Wisconsin.',
#  'Naomi Scott played Darth Maul in Lemonade Mouth.',
#  'The Minnesota Vikings is a National Football League team.',
#  'L.A. Law is a television series that categorizes as a legal drama.',
#  'Paradise was released in 2012.',
#  'Dirt was produced by ABC studios and Coquette Productions.',
#  'Arsenic and Old Lace had its release delayed by 3 months.',
#  'The Belko Experiment is an American horror film released in 2016.',
#  'Psychology has been disqualified from being a social science.',
#  'Apple was founded in 1979.',
#  'Moscow is a city in Russia.',
#  'The term cult film was first used in the 1970s.',
#  'The September 11 attacks caused at least $10 billion in property damage.',
#  "The second longest of Shakespeare's plays after Hamlet is Richard III.",
#  'Kathy Bates was born on June 28, 1948.',
#  'Joseph Barbera was an American director.',
#  'Penny Dreadful started in 2017.',
#  'There is a video game called Overwatch (video game).',
#  'The Lion King was released before 2000.',
#  'Before We Go was previously titled Fury.',
#  'Stevie Nicks released an album that reached platinum status.',
#  "Overwatch's playable characters are categorized into four groups.",
#  'Andrew Wood died in 1977.',
#  'James McAvoy starred in Children of Dune.',
#  'John Constantine is a real person.',
#  "The Portuguese Empire was one of world history's largest empires.",
#  'Eddie Vedder is a performer.',
#  'Kenny Rogers released the album, Kenny in 2005.',
#  'Kenny Rogers released the album, Kenny in 2005.',
#  'Larry Buttrose wrote Cafe Royale.',
#  'Elementary stars Lucy Liu.',
#  'Elementary stars Lucy Liu.',
#  'Farrah Fawcett acted in the romantic comedy Love is a Funny Thing.',
#  'X-Men: Days of Future Past is based on the DC Batman comics.',
#  'San Junipero is from Britain.',
#  'Alex Rodriguez never hit a home run.',
#  'John F. Kennedy ran against Andrew Jackson in the 1960 presidential election.',
#  'Gift of the Night Fury only stars the voices of actors and actresses born in October.',
#  'Gift of the Night Fury only stars the voices of actors and actresses born in October.',
#  "Schindler's List was not awarded The Academy Award for Best Picture.",
#  'Juana la virgen is a telenovela written by Perla Farias.',
#  'The Champ stars an American.',
#  'Monarch of the Glen is a drama from Britain.',
#  'Robert Redford is a film director.',
#  'Best Director was a nomination Beasts of the Southern Wild received.',
#  'The Los Angeles Lakers hold the NBA record for longest winning streak.',
#  'The Philippines is industrial.',
#  'Joe Manganiello has appeared in a movie.',
#  'Veronika Decides to Die is authored by Roberta Hanley.',
#  'Sully is a Tom Hanks movie.',
#  'Walter Matthau is incapable of winning anything.',
#  'Lisa Kudrow appeared on Showtime.',
#  'Myles Kennedy has released albums.',
#  'Jane Fonda worked with Lily Tomlin in a show.',
#  'Imagine Dragons was named the "Breakthrough Band of 2014."',
#  'Mike Love co-founded a band.',
#  'Apple was incorporated as Apple Computer, Inc. in January 1977.',
#  'Star Search was relaunched in 2003-04.',
#  'Canada was never the location of a French colony.',
#  'System of a Down has only sold albums in Greenland.',
#  'Led Zeppelin was first named the New Yardbirds.',
#  'Payton Manning signed with the Ontario Broncos.',
#  'Anthropology is a division of Davis Entertainment.',
#  'Kafka stars an actor.',
#  'Kafka stars an actor.',
#  'Alex Rodriguez played for the Mariners.',
#  'Charles Marie de La Condamine was born in 1701.',
#  'Pulp Fiction is written by a man.',
#  'Pulp Fiction is written by a man.',
#  'Giada De Laurentiis has been a contributor to a morning TV program.',
#  'Giada De Laurentiis has been a contributor to a morning TV program.',
#  'The Grammy Hall of Fame inducted Bohemian Rhapsody.',
#  'Hugh Jackman has a public feud with Christopher Nolan, preventing any collaboration between the two.',
#  'Hugh Jackman has a public feud with Christopher Nolan, preventing any collaboration between the two.',
#  'Cate Blanchett was nominated for an Academy Award.',
#  'Slash was born in 1965.',
#  'Drake is only German.',
#  'R. Madhavan was a cast member of 3 Idiots.',
#  'James and the Giant Peach includes Richard Dreyfuss.',
#  'Ayn Rand condemned force.',
#  'Anne Hathaway had a part in Ella Enchanted.',
#  'Oh Yeon-seo was born.',
#  'Ben Stiller was involved in the film industry in the 1990s.',
#  'Ben Stiller was involved in the film industry in the 1990s.',
#  'The Los Angeles Lakers were nicknamed "Showtime" in the 1980s.',
#  'Slovenia is bordered by the Adriatic Sea.',
#  'Italy is officially called the big meatball.',
#  'Ron Cobb was only born in the year 1954.',
#  'Just Dance was a song.',
#  'Journey is a band.',
#  'Life Is Peachy was released by Epic Records.',
#  'Sarah Silverman never wrote for a sketch comedy show.',
#  'Sarah Silverman never wrote for a sketch comedy show.',
#  'A mole is a structure.',
#  'Shahid Kapoor supports charities.',
#  'Doctor Who was written by the Ancient Greeks.',
#  'Doctor Who was written by the Ancient Greeks.',
#  'L.A. Law ended on May 19, 1994.',
#  'Jerry Seinfeld specialized in observational comedy.',
#  'Marie Curie was naturalized-German.',
#  'Honey to the B was the first album of a singer and actress from England.',
#  'Honey to the B was the first album of a singer and actress from England.',
#  'Will Ferrell is considered to be part of the Frat Pack.',
#  'Donnie Wahlberg acts with Tom Selleck.',
#  'Rogue appears in Canadian comic books.',
#  'The German Shepherd is the second-most registered breed by the American Kennel Club and The Kennel Club UK.',
#  'Diego Costa was born in October.',
#  "Ocean's Eight is a sequel to the Ocean's Trilogy.",
#  'The United Kingdom includes Scotland.',
#  'John Wick: Chapter 2 is a film.',
#  'Europe is the location of Andorra.',
#  'Axl Rose has been named one of the greatest singers.',
#  'Steffi Graf won 5 consecutive majors.',
#  'Jennifer Garner had a starring role in the film Catch Me if You Can.',
#  'Boromir is mentioned in the third and last volume of The Lord of the Rings.',
#  'Boromir is mentioned in the third and last volume of The Lord of the Rings.',
#  'Paul Simon is an actor.',
#  'Game of Thrones (season 3) is a drama set in a fantasy world.',
#  'Game of Thrones (season 3) is a drama set in a fantasy world.',
#  "Taiwan's high-tech industry plays a key role in the local economy.",
#  'London has an elected official.',
#  'London has an elected official.',
#  'Bill Gates was the largest individual shareholder of Microsoft.',
#  'The phalanx may be deployed for killing.',
#  'Robbie Collin edited The Saint.',
#  'Christianity failed to spread to Australasia.',
#  'Feels So Good was written for the album Hot.',
#  'Deadpool is not part of a film series.',
#  'Evolution was by someone born in May.',
#  'Evolution was by someone born in May.',
#  'Kmart has stores in operation in an unincorporated and organized territory of the United States.',
#  'Kmart has stores in operation in an unincorporated and organized territory of the United States.',
#  'Ancient Algeria has known many empires and dynasties, including ancient Carthaginians.',
#  'Clint Eastwood has been in films.',
#  'Gorgeous Ladies of Wrestling is a wrestling promotion for women.',
#  'Gustave Eiffel made significant contributions to aerodynamics.',
#  'Idris Elba has been nominated four times for a Golden Globe Award in acting.',
#  'Paul Rudd passed up the role he was offered in Role Models.',
#  'The Twelfth Doctor is capable of superhuman abilities.',
#  'Happy Endings had Lisa Kudrow in it.',
#  "Grace VanderWaal won the NBC TV competition show America's Got Talent.",
#  'Jennifer Hudson has won a Grammy.',
#  'Marie Antoinette died in 1793.',
#  'The Uruguay national football team won two FIFA World Cups.',
#  'Overwatch is a board game.',
#  'The Sopranos is a televised show.',
#  'Babe Ruth was active in Major League Baseball from 1914-1935.',
#  'Roger Federer plays a racket sport.',
#  'Roger Federer plays a racket sport.',
#  'La La Anthony was in November Rule and Destined.',
#  'The United States Naval Academy is in Maryland.',
#  'Tom Welling was born November 26, 1977.',
#  'In the Heart of the Sea was released in cinemas.',
#  'Blues and rock music has been played by the band AC/DC.',
#  'Naruto is incapable of being a ninja.',
#  'Marilyn Monroe is an actress.',
#  'Wyatt Earp was a constable and he was American.',
#  'Israel hosts a population of asylum seekers including illegal migrants from Sudan.',
#  'The American Broadcasting Company has a nickname.',
#  'Cindy McCain is married to a 2008 rugby champion.',
#  'Leonardo DiCaprio is a fish.',
#  'T-Pain is the founder of a record label imprint established in 2005.',
#  'Beyoncé was given a music award.',
#  'Alan Ladd failed to become television producer.',
#  'VHS was released in late 1976 in Japan.',
#  'Pixar was funded by an Indian industrial designer.',
#  'Pixar was funded by an Indian industrial designer.',
#  'The Chernobyl disaster ultimately involved more than 500,000 workers.',
#  'Frédéric Auguste Bartholdi was a painter.',
#  'The Beatles were formed in London.',
#  'The Beatles were formed in London.',
#  'Kumail Nanjiani has declined to act in any movies.',
#  'Hacksaw Ridge made money.',
#  'In 2010, Kick-Ass was released.',
#  'Harry Potter confronts someone in Harry Potter and the Deathly Hallows.',
#  'Sophie Turner appeared in movies in 2013.',
#  'Farrah Fawcett was the subject of an NBC documentary.',
#  'Tiger Woods has not competed in a golf tournament.',
#  'Brian Eno was born in England.',
#  'Brian Eno was born in England.',
#  'Portugal does not share a border with Spain.',
#  'Steven Knight was born in 1959.',
#  'Suits is a show about lawyers.',
#  'Tom Hanks has been granted at least three awards.',
#  'Dwyane Wade was rejected for the All-Rookie team.',
#  'The Homesman features American actor John Lithgow.',
#  "Star Wars' soundtrack was recorded in England.",
#  'The cast of The Playboy Club includes Leah Renee.',
#  'The Portuguese Empire was an empire in world history.',
#  "Chris Froome's parents are people.",
#  'Shueisha is a publisher headquartered in Maine.',
#  'Friendship has been studied in academic disciplines like anthropology.',
#  'Belgium is comprised of three regions.',
#  "Apple Inc.'s consumer software lacks the iOS operating system.",
#  'Kris Wu starred in a Chinese film called Journey to the West.',
#  'Super Metroid is a movie sequel.',
#  'One America News Network is abbreviated as OANN.',
#  'Jennifer Garner is a board member of Save the Children.',
#  'The Portuguese Empire existed during the Renaissance.',
#  'One actor is Scott Eastwood.',
#  'Tall Story is a romantic comedy club.',
#  'X-Men: Days of Future Past is a novel based on X-Men characters in comics.',
#  'Richard Eyre is a television director.',
#  'Furious 7 began principal photography in the summer of 2013.',
#  'Prakash Jha is an actor.',
#  'Splatoon 2 is the only game in its franchise.',
#  'Nepal was ruled by the Shah dynasty until 2008.',
#  'Nepal was ruled by the Shah dynasty until 2008.',
#  'The interior of Uranus is only composed of gas.',
#  'Sriti Jha plays the lead role in a TV show.',
#  'There is a film called Absolute Beginners.',
#  'Qatar borders London.',
#  'Qatar borders London.',
#  'The Amanda Show aired from 1999 to 2002.',
#  'Brock Lesnar is signed to a Japanese mixed martial arts promotion.',
#  'The Hangover Part III includes Justin Bartha.',
#  'Lee Harvey Oswald assassinated the 35th President of the United States.',
#  'Lee Harvey Oswald assassinated the 35th President of the United States.',
#  'In & Out is directed by James Cameron.',
#  'Tom Felton is a person.',
#  'Louis Tomlinson appeared in a TV drama.',
#  'Louis Tomlinson appeared in a TV drama.',
#  'Louis Tomlinson appeared in a TV drama.',
#  'Kalpana Raghavendar is an artist.',
#  'Luke Evans had his Hollywood breakthrough role starring in a play.',
#  'Luke Evans had his Hollywood breakthrough role starring in a play.',
#  'Emily Ratajkowski was visible in the "Blurred Lines" music video.',
#  '10 Cloverfield Lane stars the actor John Gallagher, Jr.',
#  'Chris Froome rides under a British license.',
#  'Olivia Munn failed to be credited as Lisa Munn.',
#  'Batman is yet to be released.',
#  'Marlon Brando is an actor who was in Mutiny on the Bounty.',
#  "None of lung cancer's symptoms is chest pains.",
#  'Iran has 21 UNESCO World Heritage Sites.',
#  'The Taj Mahal attracts significantly less than 7-8 million visitors a year.',
#  'Lisbon is in Portugal.',
#  'Arya Stark is the daughter of Lady Catelyn Stark.',
#  'Selene serves as the central character in a film written by Danny McBride in 2001.',
#  'Selene serves as the central character in a film written by Danny McBride in 2001.',
#  'Pulp Fiction is an American black comedy neo-noir film released in 1994.',
#  'Dan Aykroyd has received zero Academy Award nominations.',
#  'Dhool was directed by Dharani.',
#  'Watchmen was number 91 on The Comics Journals list of the top 100 comics of the 20th century that was published in 2001.',
#  'Watchmen was number 91 on The Comics Journals list of the top 100 comics of the 20th century that was published in 2001.',
#  'Android has had prosperity.',
#  'Saddam Hussein died in 1937.',
#  'Tim Rice has collaborated with someone.',
#  'Hugo Weaving is in zero movies.',
#  'Time Lords have time machines.',
#  'Arsenic and Old Lace was released in 1964.',
#  'The Catalyst is a rock song.',
#  'Indiana Jones has been portrayed by Corey Carrier.',
#  'Umbrella is a single.',
#  'Sandra Bullock stars in The Proposal.',
#  'Martin Luther King Jr. worked on segregated housing in earnest.',
#  'FC Barcelona was awarded five trophies.',
#  'The Great Buck Howard was directed by Ingmar Bergman.',
#  'John McEnroe is famous for his aggressive behavior on the court.',
#  "John Mayer's first EP was released while he was signed to Columbia Records.",
#  'Dirty Diana is by Michael Jackson.',
#  "American Gods' adaptation began airing.",
#  'Adrienne Bailon is an American actress.',
#  'Marlon Brando was in any movie but Julius Caesar.',
#  'Up All Night was released by Syco Records in 2011.',
#  'Little Miss Sunshine was filmed over 30 days beginning on June 6, 2005.',
#  'IO Theater is a place where people train.',
#  'Coke Boys Records was founded by an American Rapper.',
#  'John McCain was a presidential nominee in 2008.',
#  'John McCain was a presidential nominee in 2008.',
#  'Gia is a work.',
#  '21 Jump Street was released by Columbia Pictures in 2002.',
#  'Kuala Lumpur has the Petronas Twin Towers.',
#  'The television series Fargo has an anthology format, setting each season in a different era with a different story and cast.',
#  'An annual training camp is hosted by the Carolina Panthers.',
#  'Ronaldo Maczinski is Irish.',
#  'Born This Way is a piece of music.',
#  'By 1997, Andre Agassi was number 141 in the world.',
#  'Charles, Prince of Wales was a grandchild of a king.',
#  'Man of Steel is a superhero movie from 2013.',
#  'Kate Beckinsale was directed by James Ivory.',
#  'Kate Beckinsale was directed by James Ivory.',
#  'Shakira is a performer.',
#  'Michael Schumacher is a professional writer',
#  'Bridget Moynahan was cut from Lord of War.',
#  'There is a mosque in the Taj Mahal.',
#  "Cry Freedom wasn't shot in Kenya.",
#  'In the United States presidential election of 1972, Richard Nixon was a candidate.',
#  'There is a cultural attraction called the Museum of Science and Industry.',
#  'Carrie Fisher wrote a book.',
#  'Anil Kapoor has never been a producer.',
#  'Adolf Hitler encouraged settler colonialism.',
#  'Adolf Hitler encouraged settler colonialism.',
#  'Before Night Falls is a film.',
#  'An example of a Christmas comedy film is Home Alone.',
#  'Steven Price (composer) worked on the film Gravity.',
#  'The 1991 NBA Finals had the Lakers in it.',
#  'Google has been the second most valuable brand in the world for 4 blue years.',
#  'Instagram is a photo-sharing application.',
#  'Snooki & Jwoww was renewed by at least one channel.',
#  'Snooki & Jwoww was renewed by at least one channel.',
#  'The Eagles broke up in 1980.',
#  'Black Widow is Russian.',
#  'Portugal is the 5th most peaceful country in the world and it also features a high-income advanced economy and the 18th highest social progress in the world.',
#  'A temperate seasonal climate influences Berlin.',
#  'Twitter had about 1.6 billion search queries per day in 2012.',
#  'Ramadan is the ninth calendar month in Islam.',
#  'The self-empowerment of the LGBT community is discussed in Born This Way.',
#  'Mao Zedong lived until 1976.',
#  'The Hangover Part III includes Bradley Cooper, Ed Helms, Zach Galifianakis, Justin Bartha, and Ken Jeong, Jeffrey Tambor, Heather Graham, Mike Epps, Melissa McCarthy and John Goodman.',
#  'Steven Tyler was active in the early 1980s.',
#  'Wikipedia has articles in only english.',
#  'Ellyse Perry is a man.',
#  'American Idiot has not had five successful singles.',
#  'Wyatt Earp was an actor.',
#  'Toronto is the least populous city in Canada.',
#  'Toronto is the least populous city in Canada.',
#  "Paul is Steve Jobs' middle name.",
#  'Destiny was released for the console Playstation 4.',
#  "Heather Graham played the title character in the series Emily's Reasons Why Not in 2010.",
#  'Battle Studies World Tour was a global tour.',
#  'Samuel L. Jackson was in the M. Night Shyamalan film Unbreakable.',
#  'Singapore is south of Indonesia.',
#  'Jennifer Hudson was a finalist of American Idol.',
#  "Hong Kong is incapable of being consistently ranked as the world's most freest economic entity.",
#  'Manchester City F.C. was bought by the Abu Dhabi United Group.',
#  'Unapologetic is a work.',
#  'Andre Agassi is a golfer.',
#  'Liverpool F.C. was managed by Bill Shankly.',
#  'Liverpool F.C. was managed by Bill Shankly.',
#  'Bangladesh is a founding member of nationalism.',
#  'Jon Pertwee took part in Worzel Gummidge.',
#  'Lee Child was born on October 29.',
#  'Tequila is incapable of being made in Mexico.',
#  'Michael Phelps holds three long course world records for swimming.',
#  'Donald Glover never released an album.',
#  'FC Barcelona was ranked second in the IFFHS Club World Ranking for 2015.',
#  'Courteney Cox appeared on a show created by David Crane and Marta Kauffman.',
#  'Courteney Cox appeared on a show created by David Crane and Marta Kauffman.',
#  'Chris Pine appeared in a 2012 American romantic comedy spy film.',
#  'Chris Pine appeared in a 2012 American romantic comedy spy film.',
#  'Ratatouille was directed by one person.',
#  'Kurt Angle won a gold medal in freestyle wrestling at the 1995 World Wrestling Championships.',
#  'Iron Fist was created by Damon Lindelof.',
#  'Dangerous Beauty is a 1990 film.',
#  'The Avengers (2012 film) features Chris Evans.',
#  'Jerry Goldsmith failed to collaborate with anybody during his career.',
#  "Charles, Prince of Wales sponsors The Prince's Charities.",
#  'Grizz Chapman was on 30 Rock.',
#  'Nicki Minaj is a person.',
#  'Margaret of Valois was imprisoned.',
#  'The Dayton Agreement was formally signed in Paris in 1995.',
#  'As the World Turns went away and an American talk show debuted on October 18, 2010 in its place.',
#  'Princess Agents is a novel adaptation.',
#  'The Vampire Diaries only aired two seasons.',
#  'The Ten Commandments is reviewed by Cecil B. DeMille.',
#  "The Bends was released in the 1990's.",
#  'Alandi is only a city.',
#  'A singer in Got a Girl starred in Final Destination 3.',
#  'A singer in Got a Girl starred in Final Destination 3.',
#  'Peggy Sue Got Married was directed by an American director.',
#  'Role Models is a film.',
#  'Gerald Ford was the United States president after Richard Nixon.',
#  'Will Ferrell worked on a film.',
#  'Marshall McLuhan predicted his own death.',
#  'Walt Disney founded a company.',
#  'Brock Lesnar won against Randy Couture.',
#  'Guam was employed by America.',
#  'Sweden is a Scandinavian country.',
#  "One of Future's studio albums was published in 2017.",
#  "One of Future's studio albums was published in 2017.",
#  'David Dhawan is a director of films.',
#  'This Sporting Life was directed by a director born in 1919.',
#  'This Sporting Life was directed by a director born in 1919.',
#  'International Relations includes technology and engineering, economics, communication studies, history, international law, demography, philosophy, geography, social work, sociology, anthropology, criminology, psychology, gender studies, cultural studies, culturology, and diplomacy, globalization, diplomatic relations, state sovereignty, international security, ecological sustainability, nuclear proliferation, nationalism, economic development, global finance, as well as terrorism and organized crime, human security, foreign interventionism, and human rights, as well, as, more recently, comparative religion.',
#  "Underworld's main character is a supernatural creature.",
#  'Avenged Sevenfold released an album.',
#  'Brock Lesnar defeated someone.',
#  'Three Days of the Condor includes a Swedish actor.',
#  'Three Days of the Condor includes a Swedish actor.',
#  "Tyra Banks presented America's Got Talent.",
#  "Tyra Banks presented America's Got Talent.",
#  'Romelu Lukaku is a golfer.',
#  'Toy Story is a movie of the buddy comedy adventure genres.',
#  'Al Capone was not prosecuted for tax evasion.',
#  'Chet Atkins produced records for Dolly Parton.',
#  'Trevor Baxter went to college at Dulwich College.',
#  'A Song of Ice and Fire is part of an American book series called A Game of Thrones.',
#  'Many voice actors act in Timon & Pumbaa.',
#  'Jeff Bridges played a role in an American Revisionist Western film.',
#  'Jeff Bridges played a role in an American Revisionist Western film.',
#  'Zach Galifianakis starred in a film.',
#  'Nigeria is one of the countries in the Next Eleven.',
#  'Nigeria is one of the countries in the Next Eleven.',
#  'Angela Lansbury got significant recognition for her acting performance in The Manchurian Candidate.',
#  'Murray was played by Keegan-Michael Key in Hotel Transylvania 2.',
#  'Born Naked is an album.',
#  'Rock music incorporated music genres like a type of blues music distinguished by the use of electric amplification for musical instruments known as electric blues.',
#  'Rock music incorporated music genres like a type of blues music distinguished by the use of electric amplification for musical instruments known as electric blues.',
#  'Reba McEntire sang on radio shows.',
#  'The Constitution of Medina was written by Muhammad.',
#  'The Constitution of Medina was written by Muhammad.',
#  'Sleep can be disrupted by medical conditions.',
#  'Frank is by a person.',
#  'A German-American fashion model starred in The Host.',
#  'A German-American fashion model starred in The Host.',
#  'Robert Redford guest starred on Perry Mason.',
#  'Katie Stevens is Australian.',
#  'Haiti is a member of the World Trade Organization.',
#  'Anne Hathaway debuted in the Fox television series Get Real.',
#  'Twitter has more than one office.',
#  'Venus Williams has won a tournament.',
#  'Red is inspired by a comic book series.',
#  'J. Cole is a hip hop recording artist.',
#  'The cast of The Playboy Club includes David Krumholtz.',
#  'Portugal maintains a unitary semi-presidential republican form of government which means that the president exists alongside the prime minister and the cabinet and the central government is supreme.',
#  'Portugal maintains a unitary semi-presidential republican form of government which means that the president exists alongside the prime minister and the cabinet and the central government is supreme.',
#  'Randy Orton is a squid.',
#  'Rainn Wilson graduated in the 80s.',
#  'Zeus is the child of Cronus and Rhea.',
#  'Matt Kuchar is a professional golf player.',
#  'Burundi is only populated by Tutsis.',
#  'Foo Fighters was created by a name reported by aircraft pilots.',
#  'Nickelodeon has weekday programs.',
#  'Arrested Development won six Primetime Emmy Awards.',
#  'Jim Carrey has worked with director Don Scardino.',
#  'Jim Carrey has worked with director Don Scardino.',
#  'Eminem only performs alone.',
#  'David Thewlis has performed.',
#  'In 1968, Led Zeppelin formed.',
#  'Dwyane Wade played for Chicago.',
#  'Champion was based off of a Ring Lardner story.',
#  "My Bloody Valentine 3D's editor was Patrick Lussier.",
#  'Dwight Schrute was based on Gareth Keenan.',
#  'Beasts of the Southern Wild was nominated for an award.',
#  'Transformers (film) is based on a toy line created by Hasbro.',
#  "Laura Prepon portrayed Donna Pinciotti in That '70s Show.",
#  'Charles Dickens was not English.',
#  'Michael Fassbender was in the NBC miniseries Band of Brothers.',
#  'Keeping Up with the Joneses had a budget.',
#  'RenderMan was developed by Pixar.',
#  'The Homesman features at least one American actor.',
#  'Peter Cetera was an artist.',
#  'Heartbreak Ridge was filmed in Technicolor.',
#  'Cape Fear features a cameo from Robert Mitchum and it is directed by Martin Scorsese.',
#  'Oliver Reed was in a movie.',
#  'Oliver Reed was in a movie.',
#  'Maggie Smith is an actress.',
#  'Jackie Robinson died in the seventies.',
#  "Eric Trump's father's birthday is June 14.",
#  "Eric Trump's father's birthday is June 14.",
#  'Ethiopia is a state.',
#  'On February 18, 1949, Gary Ridgway was born.',
#  'Eva Longoria has starred in Harsh Times.',
#  'Angela Lansbury was born to a family that was upper-middle-class.',
#  'The World Science Festival is produced by the World Science Foundation.',
#  'XXx: Return of Xander Cage has the writer F. Scott Frazier.',
#  'Kid Rock is an artist.',
#  'Hillary Clinton was employed in the Obama administration.',
#  'The Ten Commandments (1956 film) is a 1956 American movie.',
#  'Kangana Ranaut was alive.',
#  'Marlon Brando took part in a film adapted from the work of a writer of more than 40 books.',
#  'Marlon Brando took part in a film adapted from the work of a writer of more than 40 books.',
#  'Ringo Starr replaced Pete Best.',
#  'Oscar Robertson is American.',
#  'Wyoming is the least populous state in the United States.',
#  'Heartland has no nationality.',
#  'Following was only directed by Martin Scorsese.',
#  'Jacinda Barrett is a person.',
#  "Ubisoft created Assassin's Creed.",
#  'Edgar Award honors the best in TV.',
#  'Lewis Hamilton is a race car driver.',
#  "Girls' Generation features Taeyeon.",
#  'Pirates of the Caribbean is set in a fictional future setting.',
#  'Ad-Rock is single.',
#  'Gianluigi Buffon has been named Serie A Goalkeeper of the Year.',
#  'Rhona Mitra writes songs.',
#  'Steven Soderbergh directed a biographical film and received acclaim.',
#  'Dragon is taken from a linguistic system indigenous to sections of the Eastern Mediterranean.',
#  'Dragon is taken from a linguistic system indigenous to sections of the Eastern Mediterranean.',
#  'Following a stroke, Lauren Bacall died.',
#  'Led Zeppelin II was only released in Japan on October 31, 1969.',
#  'Brian Helgeland won an award.',
#  'De Profundis was written during an imprisonment.',
#  "Planet of the Apes' director was Franklin J. Schaffner.",
#  'Radioactive has won a Grammy.',
#  'The hero of the Odyssey is Harry Potter.',
#  'Houston economy is incapable of having a base in energy.',
#  'Nice & Slow was released after 1990.',
#  'Lewis Hamilton is a racecar driver in F1.',
#  'Ben Stiller did not direct or star in the film Zoolander.',
#  'Ben Stiller did not direct or star in the film Zoolander.',
#  'Nicole Scherzinger made progress towards the eventual creation of a clothing brand.',
#  'Turkey ended accession negotiations with the European Union.',
#  'Selena Gomez starred in the 2013 film Spring Breakers.',
#  'Selena Gomez starred in the 2013 film Spring Breakers.',
#  'One of the leads in Transformers: Age of Extinction is an American rapper.',
#  'One of the leads in Transformers: Age of Extinction is an American rapper.',
#  'Emilio Estevez acts.',
#  'The Gheg of southern Austria form the oldest continuous ethnic Albanian diaspora.',
#  'Mauritius has high political freedom.',
#  'Star vs. the Forces of Evil is an American animated series produced by Disney Television Animation.',
#  'Before the year 2000, The Ren & Stimpy Show was created.',
#  "Krysten Ritter was on 'Til Death.",
#  'The Incredible Hulk is the second episode in a series.',
#  'A Perfect Circle was formed in a year.',
#  'Farrah Fawcett forfeited four additional Golden Globe nominations for her 1980s work in TV movies.',
#  'Judy Greer has not appeared in multiple films.',
#  '25 was released in November and was successful.',
#  'There is an actress name Eliza Dushka.',
#  'Little Mix is a Ugandan girl group.',
#  'Zindagi Na Milegi Dobara has a director named Laila.',
#  'Baahubali: The Beginning was released in 2000.',
#  'Miley Cyrus is in the music industry.',
#  'Miley Cyrus is in the music industry.',
#  'Miley Cyrus is in the music industry.',
#  'Miley Cyrus is in the music industry.',
#  'Miley Cyrus is in the music industry.',
#  'Christina Aguilera has avoided the music industry entirely.',
#  'Bill Gates was a chairman of Microsoft.',
#  'Keanu Reeves played bass guitar for the band Becky in 2001.',
#  'Gone with the Wind is a long-length fiction work.',
#  'Gone with the Wind is a long-length fiction work.',
#  'Gold has a distinctive color.',
#  'Lodging is done in a car.',
#  'K-pop Star 2 featured Park Jin-young as a judge.',
#  'The Khmer Empire was weak.',
#  'Gwen Stefani received a World Music Award.',
#  "Buddy Holly's birth name was Johnny Bravo.",
#  'Liev Schreiber is an American actor.',
#  'Oakland, California is a city populated by 419,267 people.',
#  'Alex Rodriguez is an athlete.',
#  "Nazi Germany happened after Hitler's death.",
#  "Keturah was Abraham's wife.",
#  'Game of Thrones (season 1) featured Scottish stage and television actor Iain Glen.',
#  'Game of Thrones (season 1) featured Scottish stage and television actor Iain Glen.',
#  'Patrick Bateman is the villain protagonist of the game American Psycho.',
#  'Jimmy Carter was not a president.',
#  'Andy Dwyer appears in a series.',
#  'Andy Dwyer appears in a series.',
#  'Extracorporeal shockwave therapy (ESWT) is unused in cardiology.',
#  'Yusuke Murata was the illustrator of an American football manga.',
#  'There is a director named Fred Savage.',
#  'Where the Wild Things Are was put out in December.',
#  'Faith Evans works solely as an actress.',
#  'Hot was by a pop singer from Britain.',
#  'Natalie Portman was not in Star Wars.',
#  'Havoc went to the public on November 29, 2005.',
#  'Gabriel Aubry and Halle Berry have a child.',
#  'Sharon Tate was a model.',
#  'Nick Kroll has a leading role in the comedy Get Him to the Greek.',
#  'Inhumans are DC characters.',
#  'Cloud Atlas has been described as "a sort of pointillist mosaic."',
#  "Thirteen is based on Nikki Reed's death at age 12 and 13.",
#  'Caitlyn Jenner did not change her gender.',
#  'James Taylor released a compilation album.',
#  'James Taylor released a compilation album.',
#  'Slovakia joined in Eurozone in November 2009.',
#  'Little Boy was dropped by Enola Gay.',
#  'Taylor Schilling in the main cast of the series Orange is the New Black.',
#  'Curse, Inc. is used by a game.',
#  'Huginn is a raven that often travels with Odin.',
#  'Iain Glen is only a film actor.',
#  'The Billboard charts included Just Dance.',
#  'Mickey Rooney was in a film based on the novel The Black Stallion by Walter Farley.',
#  'Mickey Rooney was in a film based on the novel The Black Stallion by Walter Farley.',
#  'Louise Simonson is from America.',
#  'Nelson Mandela was President of South Africa from 1994 to 1999.',
#  'Janet Varney is a German.',
#  'Lust for Life is based on a 1934 novel.',
#  'Alex Rodriguez has had a 22-year career.',
#  'Lee Min-ho is a German singer.',
#  "Destiny's criticism centered mostly around the game's storyline and post-campaign content.",
#  'No artists lived in Amsterdam.',
#  'Australia is a country in the Pacific Ocean.',
#  'Australia is a country in the Pacific Ocean.',
#  'Event management includes decor.',
#  'The New York Giants play professionally.',
#  'Shawn Mendes is represented by a Canadian record label.',
#  'Shawn Mendes is represented by a Canadian record label.',
#  'The Secret Life of Us failed to ever air anywhere.',
#  'The Dark Knight is set in Metropolis.',
#  'Jamie Foxx was incapable of portraying Ray Charles in Ray.',
#  'A cause of anti-nuclear antibodies are are anti-sp100 antibodies.',
#  'Emmy Rossum had a prominent role in a movie of which Maggie Greenwald was the director.',
#  'Emmy Rossum had a prominent role in a movie of which Maggie Greenwald was the director.',
#  'The divine right of kings was brought into action by Henry VIII when he changed the English constitution.',
#  'How to Lose Friends & Alienate People stars Simon Pegg, Kirsten Dunst, Danny Huston, Gillian Anderson, Megan Fox and Jeff Bridges, alongside Max Minghella and Margo Stilley.',
#  'Equidae includes some species known only from fossils.',
#  'Ty Cobb was born in rural Connecticut.',
#  'Psychological findings link to research and perspectives from an academic discipline.',
#  'Psychological findings link to research and perspectives from an academic discipline.',
#  'Felicity Jones was nominated for an Academy Award for Best Actress.',
#  'There is a screenwriter named Jim Rash.',
#  'Paris hosts the French Open.',
#  'Toy Story is a television show.',
#  'Kalpana Raghavendar is a person who writes songs.',
#  'The Odia language is used to communicate in Chhattisgarh.',
#  'Melisandre was left out of A Storm of Swords (2000).',
#  'Queen Latifah has won at least one Screen Actors Guild Award.',
#  'Laadla was released.',
#  "Stars Dance is Selena Gomez's debut album.",
#  "Ileana D'Cruz starred in a movie.",
#  "Ileana D'Cruz starred in a movie.",
#  "Ileana D'Cruz starred in a movie.",
#  "Ileana D'Cruz starred in a movie.",
#  "Ileana D'Cruz starred in a movie.",
#  'Jet Li was in The Forbidden Kingdom with Jackie Chan.',
#  'Suits stars a dog named Harvey Specter.',
#  'Dr. Dre established his own country.',
#  'Derrick Rose was not born in the Chicago area.',
#  'Paul Newman was an actor.',
#  'Charles I of England was a pauper.',
#  'SF are the initials used to represent San Francisco.',
#  'Billy Clanton was unrelated to Newman Clanton.',
#  'Katherine Heigl appeared in a science fiction television series.',
#  'Katherine Heigl appeared in a science fiction television series.',
#  'Stagira is the birthplace of Plato.',
#  'Cara Delevinge did not win the Model of the Year award.',
#  'David Harbour was born on June 2nd, 1991.',
#  'In Burundi, there are 21 registered parties.',
#  'Where the Wild Things Are was released in Australia.',
#  'Furious 7 is a TV show.',
#  'Sarah Paulson received a Golden Globe Award nomination.',
#  'Caroline, Princess of Hanover is married to anyone but an heir.',
#  "Grey's Anatomy is filmed in the United States.",
#  "Grey's Anatomy is filmed in the United States.",
#  'Nikolaj Coster-Waldau was not in a Danish thriller film.',
#  'Nikolaj Coster-Waldau was not in a Danish thriller film.',
#  'Sean Connery won three Golden Globes.',
#  'Gujarat is in Western Boston.',
#  'Cancer is a group of diseases involving abnormal cell proliferation.',
#  'Marion Cotillard portrayed someone.',
#  'Chandni was created in 2001.',
#  'Ronald Reagan worked for the president of the United States.',
#  'Kill Bill: Volume 2 is about the Bride continuing her revenge against Bill.',
#  'Music journalism is critical of popular music topics.',
#  'Tom Felton is an actor.',
#  "The Marvel Cinematic Universe's first phase ended.",
#  "Hulk's coloration has not varied.",
#  'Roger Federer avoided tennis entirely.',
#  'Andy Kaufman was an artist.',
#  'Bruce Springsteen was a Kennedy Center Honors recipient in 2009.',
#  'Planet of the Apes is a squid.',
#  'Hayden Panettiere is a person.',
#  'A Song of Ice and Fire is by George Raymond Richard Martin.',
#  'A Song of Ice and Fire is by George Raymond Richard Martin.',
#  'Oh Yeon-seo worked in a group.',
#  'Mango is the national fruit of the Philippines.',
#  'George Best has been described as "the worst player to ever pull on the green shirt of Wales."',
#  'Bring It On (film) had zero involvement from Jesse Bradford.',
#  'Roald Dahl writes books.',
#  'Hypothyroidism can cause mood changes.',
#  'Jon Watts has only ever been a plumber.',
#  'Cosmopolitan as of 2011 only contains content which includes articles on dogs.',
#  'By area, Nepal is the ninety-third largest country on Earth.',
#  'Wentworth premiered on Broadway.',
#  'The Fujitsu iPAD was introduced by Fujitsu in 2002.',
#  'Cage Warriors is an MMA promotion that held its first event in London.',
#  'American Horror Story: Hotel is a season of an FX romance serialized radio series.',
#  'Lonesome Dove (miniseries) was nominated for eighteen Emmys in 1989 and won seven.',
#  'Denial was released in Europe.',
#  'Denial was released in Europe.',
#  "Avatar: The Last Airbender's antagonist is Aang.",
#  'Apple was not founded in 1976.',
#  'Conquest of the Planet of the Apes is genre fiction.',
#  'Conquest of the Planet of the Apes is genre fiction.',
#  ...]

# %%
def generate_all_tokens(arr):
    all_tokens = []
    for unprocessed_claim in tqdm_notebook(arr):
        c = utils.preprocess_article_name(unprocessed_claim)
        c = "! {} !".format(c)
        for word in c.split():
            letter_tuples = list(nltk.ngrams("#" + word + "#", 3))
            letter_grams = []
            for l in letter_tuples:
                letter_grams.append("".join(l))
            all_tokens.extend(letter_grams)
    return all_tokens

# %%
processed_claims = generate_all_tokens(claims)
processed_claims.extend(generate_all_tokens(article_list))

possible_tokens = list(set(processed_claims))

encoder = LabelEncoder()
encoder.fit(np.array(sorted(possible_tokens)))
# Out:
# HBox(children=(IntProgress(value=0, max=125051), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=125051), HTML(value='')))
# LabelEncoder()

# %%
feature_encoder = {}
for idx, e in tqdm_notebook(enumerate(encoder.classes_)):
    feature_encoder[e] = idx
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
def tokenize_claim(c, enc):
    """
    Input: a string that represents a single claim
    Output: a list of 3x|vocabulary| arrays that has a 1 where the letter-gram exists.
    """
    encoded_vector = []
    c = utils.preprocess_article_name(c)
    c = "! {} !".format(c)
    for ngram in nltk.ngrams(nltk.word_tokenize(c), 3):
        arr = sparse.lil_matrix((3, len(enc.__dict__['classes_'])))
        for idx, word in enumerate(ngram):
            for letter_gram in nltk.ngrams("#" + word + "#", 3):
                s = "".join(letter_gram)
                letter_idx = feature_encoder[s]
                arr[idx, letter_idx] = 1
        encoded_vector.append(arr)
    return encoded_vector

# %%
load_processed_claims = True

# %%
if load_processed_claims:
    with open("all_data.pkl", "rb") as f:
        all_data = pickle.load(f)
else:
    all_data = []

    article_set = set(article_list)

    def process_claim(idx):
        data = {}
        data['claim'] = tokenize_claim(claims[idx], encoder)
        data['positive_article'] = tokenize_claim(article_list[idx], encoder)
        negative_articles = np.random.choice(list(article_set - set(claim_to_article[claims[idx]])), cdssm.J)
        negative_articles = [tokenize_claim(i, encoder) for i in negative_articles]
        data['negative_article'] = negative_articles
        return data

    all_data = [process_claim(i) for i in tqdm_notebook(range(len(claims)))]
    
    with open("all_data.pkl", "wb") as f:
        pickle.dump(all_data, f)
    #all_data = Parallel(n_jobs=cpu_count(), verbose=1, prefer="threads")(delayed(process_claim)(i) for i in range(len(claims)))

# %%
import torch 
import torch.nn as nn
import torchvision.datasets as dsets
import torchvision.transforms as transforms
from torch.autograd import Variable
import torch.nn.functional as F
import cdssm

# %%
model = cdssm.CDSSM()

# %%
def to_torch_sparse_tensor(M):
    M = M.tocoo().astype(np.float32)
    indices = torch.from_numpy(np.vstack((M.row, M.col))).long().cuda()
    values = torch.from_numpy(M.data).cuda()
    shape = torch.Size(M.shape)
    T = torch.sparse.FloatTensor(indices, values, shape)
    return T

# %%
all_gpu_data = []
def process_gpu_data(i):
    data = {}
    data['claim'] = Variable(to_torch_sparse_tensor(sparse.vstack(all_data[i]['claim'])))
    data['positive_article'] = Variable(to_torch_sparse_tensor(sparse.vstack(all_data[i]['positive_article'])))
    data['negative_article'] = [_ for j in range(cdssm.J)]
    for j in range(cdssm.J):
        item = all_data[i]['negative_article'][j]
        if len(item)>0:
            data['negative_article'][j] = Variable(to_torch_sparse_tensor(sparse.vstack(all_data[i]['negative_article'][j])))
    return data

all_gpu_data = Parallel(n_jobs=cpu_count(), verbose=1, prefer="threads")(delayed(process_gpu_data)(i) for i in range(10000))

# %%
all_gpu_data[0]

# %%
all_gpu_data = []
for i in tqdm_notebook(range(1, len(all_data))):
    data = {}
    data['claim'] = Variable(to_torch_sparse_tensor(sparse.vstack(all_data[i]['claim'])))
    data['positive_article'] = Variable(to_torch_sparse_tensor(sparse.vstack(all_data[i]['positive_article'])))
    data['negative_article'] = [_ for j in range(cdssm.J)]
    for j in range(cdssm.J):
        item = all_data[i]['negative_article'][j]
        if len(item)>0:
            data['negative_article'][j] = Variable(to_torch_sparse_tensor(sparse.vstack(all_data[i]['negative_article'][j])))
    all_gpu_data.append(data)
# Out:
# HBox(children=(IntProgress(value=0, max=125049), HTML(value='')))

# %%
model

# %%
LETTER_GRAM_SIZE = 3 # See section 3.2.
WINDOW_SIZE = 3 # See section 3.2.
TOTAL_LETTER_GRAMS = len(encoder.__dict__['classes_']) # Determined from data. See section 3.2.
WORD_DEPTH = WINDOW_SIZE * TOTAL_LETTER_GRAMS # See equation (1).
# Uncomment it, if testing
# WORD_DEPTH = 1000
K = 300 # Dimensionality of the max-pooling layer. See section 3.4.
L = 128 # Dimensionality of latent semantic space. See section 3.5.
J = 4 # Number of random unclicked documents serving as negative examples for a query. See section 4.
FILTER_LENGTH = 1 # We only consider one time step for convolutions.

# %%
# Loss and optimizer
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-4, momentum=0.9)

# %%
# Build a random data set.
train_set_size = int(len(all_gpu_data) * 0.8)

for i in tqdm_notebook(range(train_set_size)):
    claim = all_gpu_data[i]['claim'].to_dense()
    claim = claim.view(1, claim.shape[0] // 3, 3, -1)
    
    positive_article = all_gpu_data[i]['positive_article'].to_dense()
    positive_article = positive_article.view(1, positive_article.shape[0] // 3, 3, -1)
    
    negative_articles = []
    for j in range(cdssm.J):
        negative_article = all_gpu_data[i]['negative_article'][j].to_dense()
        negative_article = negative_article.view(1, negative_article.shape[0]//3, 3, -1)
        negative_articles.append(negative_article)
    
    y_pred = model(claim, positive_article, negative_articles)
    
    y = Variable(torch.from_numpy(np.array(labels[i])).long())
    loss = criterion(y_pred.resize(1,cdssm.J+1), y)
    print (i, loss.data[0])
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
